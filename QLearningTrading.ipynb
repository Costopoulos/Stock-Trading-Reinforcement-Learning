# %% [markdown]
# # Deep Q- learning Agent- Stock Trading

# %% [markdown]
# In this notebook, we will train an agent to trade 2 and 4 specific stocks at a time in order to maximize the profit. We will be using Deep Q-Learning.

# %% [markdown]
# ## Getting the data from the Repo

# %%
# !git clone https://github.com/Costopoulos/EV-Charging-Reinforcement-Learning.git
# Out:
# Cloning into 'EV-Charging-Reinforcement-Learning'...
# remote: Enumerating objects: 15, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 15 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (15/15), 824.00 KiB | 3.63 MiB/s, done.

# %%
# %cd EV-Charging-Reinforcement-Learning/
# Out:
# /kaggle/working/EV-Charging-Reinforcement-Learning

# %% [markdown]
# ## Imports

# %%
import keras
import random
import math
import gym
import sys
import numpy as np
import pandas as pd

from keras.models import Sequential
from keras.models import load_model
from keras.layers import Dense
from tensorflow.keras.optimizers import Adam

from datetime import datetime, timedelta
from collections import deque

# %% [markdown]
# ### Important Definitions
# <ul>
#     <li><strong>stock1_name</strong>:   This is first stock name, is Apple - aapl.us</li>
#     <li><strong>stock2_name</strong>:   This is second stock name, is Amazon - amzn.us</li>
#     <li><strong>episode_count</strong>: This is number of episodes the agent will train on. In our case it's 50</li>
#     <li><strong>start_balance</strong>: This is the initial budget, which is $10,000</li>
#     <li><strong>training</strong>:      How many days each episode will last. Defaults at 1500</li>
#     <li><strong>test</strong>:          Number of days that the test will run on. Defaults at 500 </li>
#  </ul>

# %%
class Agent:
    def __init__(self, state_size, is_eval=False, model_name=""):
        self.state_size = state_size # normalized previous days
        self.action_size = 5 # buy_1, sell_1, do Nothing, buy2, sell2
        self.memory = deque(maxlen=2000) # deque is basically a list that provides O(1) pop & append methods
        self.inventory1 = []
        self.inventory2 = []
        self.model_name = model_name
        self.is_eval = is_eval
        self.gamma = 0.95 # gamma is the discount factor. It quantifies how much importance we give for future rewards.
        self.epsilon = 1.0 # Exploration and Exploitation — Epsilon (ε) for ε - greedy
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.995
        self.model = load_model("models/" + model_name) if is_eval else self._model()

    def _model(self):
        model = Sequential()
        model.add(Dense(units=64, input_dim=self.state_size, activation="relu"))
        model.add(Dense(units=32, activation="relu"))
        model.add(Dense(units=8, activation="relu"))
        model.add(Dense(self.action_size, activation="linear"))
        model.compile(loss="mse", optimizer=Adam(learning_rate=0.0001))
        return model

    def act(self, state):
        if not self.is_eval and random.random() <= self.epsilon: # ε - greedy; act randomly if random returns sth < epsilon
            return random.randrange(self.action_size)
        options = self.model.predict(state)
        return np.argmax(options[0])

    def expReplay(self, batch_size):
        mini_batch = []
        l = len(self.memory)
        
        minibatch = random.sample(self.memory, batch_size) # mini_batch
        
        for state, action, reward, next_state, done in mini_batch:
            target = reward
            
            if not done:
                target = reward + self.gamma * np.amax(self.model.predict(next_state)[0])
              
            target_f = self.model.predict(state)
            target_f[0][action] = target
            self.model.fit(state, target_f, epochs=1, verbose=2)

        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay

# %%
class State:
    def __init__(self, data1, data2, Bal_stock1, Bal_stock2, open_cash, timestep):
        self.Stock1Price=data1[timestep] # stock 1 open price
        self.Stock2Price=data2[timestep] # stock 2 open price
        self.Stock1Blnc=Bal_stock1 # stock 1 balance
        self.Stock2Blnc=Bal_stock2 # stock 2 balance
        self.open_cash=open_cash # cash balance
        self.fiveday_stock1=self.five_day_window(data1, timestep)
        self.fiveday_stock2=self.five_day_window(data2, timestep)
        self.portfolio_value=self.portfolio_value()

    def portfolio_value(self):
        pvalue=0

        v1=self.Stock1Price * float(self.Stock1Blnc)
        v2=self.Stock2Price * float(self.Stock2Blnc)
        v3=float(self.open_cash)
        return (v1+v2+v3)
    
    def five_day_window(self,data, timestep):
        step = timestep
        if step < 5:
            return data[0]
        
        stock_5days = np.mean(data[step-5:step])

        return stock_5days
    
    def reset(self):
        self.Stock1Price=151.25 # stock 1 open price Google
        self.Stock2Price=21.845 # stock 2 open price Walmart
        self.Stock1Blnc=34 # stock 1 balance Google
        self.Stock2Blnc=221 # stock 2 balance Walmart
        self.open_cash=10000 # cash balance
        self.fiveday_stock1=151.25
        self.fiveday_stock2=21.845
        self.portfolio_value=10000
        
    def getState(self):
        res=[]
        res.append(self.Stock1Price) # stock 1 open price
        res.append(self.Stock2Price) # stock 2 open price
        res.append(self.Stock1Blnc) # stock 1 balance
        res.append(self.Stock2Blnc) # stock 2 balance
        res.append(self.open_cash) # cash balance
        res.append(self.fiveday_stock1)
        res.append(self.fiveday_stock2)        
        res.append(self.portfolio_value)

        res1=np.array([res])
        return res1

# %%
stock_name1, stock_name2, episode_count, start_balance, training, test = 'aapl.us', 'amzn.us', 12, 10000, 1500, 500

pd_data1 = pd.read_csv('data/aapl.us.txt', sep=",", header=0)
pd_data2 = pd.read_csv('data/amzn.us.txt', sep=",", header=0)

# %% [markdown]
# ## Data Pre-processing

# %% [markdown]
# In this section we will do the following:
# 1. Look at the data of Apple and Amazon stock for checking anamolies (missing data etc.). Also convert date into right format
# 2. Make sure that both the stock data is for the same time period and same days in this time period. Remove data if necessary
# 3. Look at descriptive statistics of data- mean, median, number of records
# 4. Visualize the data to see how stock price changes with time

# %% [markdown]
# #### View First Stock's data

# %%
pd_data1.head()
# Out:
#          Date     Open     High      Low    Close    Volume  OpenInt
# 0  1984-09-07  0.42388  0.42902  0.41874  0.42388  23220030        0
# 1  1984-09-10  0.42388  0.42516  0.41366  0.42134  18022532        0
# 2  1984-09-11  0.42516  0.43668  0.42516  0.42902  42498199        0
# 3  1984-09-12  0.42902  0.43157  0.41618  0.41618  37125801        0
# 4  1984-09-13  0.43927  0.44052  0.43927  0.43927  57822062        0

# %%
pd_data1.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  8364.000000  8364.000000  8364.000000  8364.000000  8.364000e+03
# mean     22.284350    22.495867    22.054244    22.281018  1.066416e+08
# std      37.763402    38.057733    37.447432    37.764469  9.935187e+07
# min       0.233050     0.235640     0.230510     0.230510  0.000000e+00
# 25%       1.137100     1.164200     1.112800     1.137100  4.384365e+07
# 50%       1.632800     1.663400     1.600600     1.628250  7.481383e+07
# 75%      23.739000    23.930500    23.335750    23.694500  1.320534e+08
# max     175.110000   175.610000   174.270000   175.610000  2.069770e+09
#
#        OpenInt
# count   8364.0
# mean       0.0
# std        0.0
# min        0.0
# 25%        0.0
# 50%        0.0
# 75%        0.0
# max        0.0

# %% [markdown]
# #### View Second Stock's data

# %%
pd_data2.head()
# Out:
#          Date  Open  High   Low  Close    Volume  OpenInt
# 0  1997-05-16  1.97  1.98  1.71   1.73  14700000        0
# 1  1997-05-19  1.76  1.77  1.62   1.71   6106800        0
# 2  1997-05-20  1.73  1.75  1.64   1.64   5467200        0
# 3  1997-05-21  1.64  1.65  1.38   1.43  18853200        0
# 4  1997-05-22  1.44  1.45  1.31   1.40  11776800        0

# %%
pd_data2.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  5153.000000  5153.000000  5153.000000  5153.000000  5.153000e+03
# mean    181.747357   183.880652   179.466684   181.769343  7.837325e+06
# std     239.611052   241.226109   237.638139   239.548391  7.594745e+06
# min       1.410000     1.450000     1.310000     1.400000  0.000000e+00
# 25%      35.500000    36.130000    35.000000    35.550000  3.779449e+06
# 50%      70.900000    72.750000    69.020000    70.700000  5.902992e+06
# 75%     242.850000   245.770000   240.670000   243.880000  8.888949e+06
# max    1126.100000  1135.540000  1124.060000  1132.880000  1.043288e+08
#
#        OpenInt
# count   5153.0
# mean       0.0
# std        0.0
# min        0.0
# 25%        0.0
# 50%        0.0
# 75%        0.0
# max        0.0

# %% [markdown]
# #### Drop Data that is not in both stock data- some days' data is missing in stock1 and some in stock2

# %%
# Convert Date to DateTime
def dateToDatetime(df1, df2):
    df1['Date'] = pd.to_datetime(df1['Date'], format='%Y/%m/%d')
    df2['Date'] = pd.to_datetime(df2['Date'], format='%Y/%m/%d')
    return df1, df2

def firstFilteringOut(df1, df2):
    if (df1['Date'][0] > df2['Date'][0]): 
        df1 = df1[df1.Date>=df2['Date'][0]]
        df1 = df1.reset_index(drop=True)
    else:
        df2 = df2[df2.Date>=df1['Date'][0]]
        df2 = df2.reset_index(drop=True)
    
    return df1, df2

# Drop columns for which data is missing in stock1 or stock2
def dropDataNotInBothStocks(df1, df2):
    df1, df2 = firstFilteringOut(df1, df2)
    list1 = df1['Date']
    list2 = df2['Date']
    diff_df1 = list(set(list1) - set(list2))
    diff_df2 = list(set(list2) - set(list1))
    
    for k in range(len(diff_df1)):
        df1_datetime_str = diff_df1[k].strftime('%Y-%m-%d 00:00:00')
        df1_datetime = datetime.strptime(df1_datetime_str, "%Y-%m-%d 00:00:00")
        for i, j in enumerate(list1):
            if j == df1_datetime:
                df1 = df1.drop([i])
    
    for k in range(len(diff_df2)):
        df2_datetime_str = diff_df2[k].strftime('%Y-%m-%d 00:00:00')
        df2_datetime = datetime.strptime(df2_datetime_str, "%Y-%m-%d 00:00:00")
        for i, j in enumerate(list2):
            if j == df2_datetime:
                df2 = df2.drop([i])
    
    df1 = df1.reset_index(drop=True)
    df2 = df2.reset_index(drop=True)
    
    return df1, df2

def preprocess2Stocks(df1, df2):
    df1, df2 = dateToDatetime(df1, df2)
    df1, df2 = dropDataNotInBothStocks(df1, df2)
    return df1, df2

# %%
pd_data1, pd_data2 = preprocess2Stocks(pd_data1, pd_data2)

# %% [markdown]
# Now the data is clean, both stock1 and stock2 have 5151 records

# %%
pd_data1['Date'][0]
# Out:
# Timestamp('1997-05-16 00:00:00')

# %%
pd_data2['Date'][0]
# Out:
# Timestamp('1997-05-16 00:00:00')

# %%
pd_data1.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  5151.000000  5151.000000  5151.000000  5151.000000  5.151000e+03
# mean     35.484689    35.816124    35.123519    35.479585  1.367661e+08
# std      43.150378    43.473086    42.805762    43.153299  1.119530e+08
# min       0.412350     0.423880     0.408530     0.413660  0.000000e+00
# 25%       1.518700     1.552100     1.488200     1.521300  6.327315e+07
# 50%      12.362000    12.710000    12.060000    12.403000  1.075093e+08
# 75%      64.097000    64.834000    63.631500    64.308500  1.764941e+08
# max     175.110000   175.610000   174.270000   175.610000  2.069770e+09
#
#        OpenInt
# count   5151.0
# mean       0.0
# std        0.0
# min        0.0
# 25%        0.0
# 50%        0.0
# 75%        0.0
# max        0.0

# %%
pd_data2.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  5151.000000  5151.000000  5151.000000  5151.000000  5.151000e+03
# mean    181.812687   183.946772   179.531361   181.834821  7.835138e+06
# std     239.634626   241.249596   237.661600   239.571842  7.594587e+06
# min       1.410000     1.450000     1.310000     1.400000  0.000000e+00
# 25%      35.500000    36.230000    35.010000    35.580000  3.777334e+06
# 50%      70.940000    72.810000    69.020000    70.730000  5.901100e+06
# 75%     243.035000   246.240000   241.015000   243.900000  8.888874e+06
# max    1126.100000  1135.540000  1124.060000  1132.880000  1.043288e+08
#
#        OpenInt
# count   5151.0
# mean       0.0
# std        0.0
# min        0.0
# 25%        0.0
# 50%        0.0
# 75%        0.0
# max        0.0

# %% [markdown]
# ### Data Visualization

# %%
# Stock1 Plot
import matplotlib.pyplot as plt
import datetime
import numpy as np

# %matplotlib inline

x1 = np.array(pd_data1['Date'])
y1 = pd_data1['Open']
y12= pd_data1['Volume']

plt.title("Apple Stock Performance Over years")
plt.xlabel("Year")
plt.ylabel("Price in $")
plt.plot(x1,y1)


ax2 = plt.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:red'
ax2.set_ylabel('volume', color=color)  # we already handled the x-label with ax1
ax2.plot(x1, y12, color=color)
ax2.tick_params(axis='y', labelcolor=color)


plt.show()

# %%
# Stock2 Plot
import matplotlib.pyplot as plt
import datetime
import numpy as np

# %matplotlib inline

x2 = np.array(pd_data2['Date'])
y2 = pd_data2['Open']
y22= pd_data2['Volume']


plt.title("Amazon Stock Performance Over years")
plt.xlabel("Year")
plt.ylabel("Price in $")

plt.plot(x2,y2)


ax2 = plt.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:red'
ax2.set_ylabel('volume', color=color)  # we already handled the x-label with ax1
ax2.plot(x2, y22, color=color)
ax2.tick_params(axis='y', labelcolor=color)


plt.show()

# %% [markdown]
# ## Split Training and Test data

# %% [markdown]
# Next step is to divide data into training and test set. This has to be done in a chronological order. So, data is divided into:
# - training set from days 0 to days 'training'
# - test set: from days 'training' to day 'training+ test'

# %%
def train_test_split(df, train_size, test_size):
    df_train = df[0:train_size]
    df_test = df[train_size:train_size+test_size]
    
    return df_train, df_test

# %%
# Split
pd_data1_train, pd_data1_test = train_test_split(pd_data1, training, test)
pd_data2_train, pd_data2_test = train_test_split(pd_data2, training, test)

# %% [markdown]
# Make the pd_data'INDEX'_test variables act like lists (have numerical indexes)

# %%
pd_data1_test = pd_data1_test.reset_index(drop=True)
pd_data2_test = pd_data2_test.reset_index(drop=True)

# %% [markdown]
# ## Initialize state and set benchmarking model

# %%
total_Prof=[]
done=False


batch_size = 64

#Benchmark Model
#In this model, we would divide 


#Initialize state and set benchmarking model


#print(df_data1)
total_Prof=[]
done=False

Act_datasize = training
batch_size = 64

#Benchmark Model

data1_train=pd_data1_train['Open']
data2_train=pd_data2_train['Open']

data1_date=pd_data1_train['Date']

Act_Bench_Stock1_Bal=int(np.floor((start_balance/4)/data1_train[0]))
Act_Bench_Stock2_Bal=int(np.floor((start_balance/4)/data2_train[0]))
Act_Bench_Open_cash=start_balance/2


### Program to calculate benchmark profit


#sell 10% of stock in 10 intervals

interval=int(Act_datasize/10)
Total_Stock1_Amount= 0
Total_Stock2_Amount= 0
stocks2Value = 0
stocks1Value = 0

Act_stocks1=np.floor(Act_Bench_Stock1_Bal /10)
Act_stocks2=np.floor(Act_Bench_Stock2_Bal /10)
#print(str(Act_stocks1))
#print(str(Act_stocks2))

remaining_stock1=Act_Bench_Stock1_Bal
remaining_stock2=Act_Bench_Stock2_Bal
ttl=0

Benchmark_Port_Value=[]


for j in range (interval,Act_datasize+1,interval):
    #print("closing prices : " + str(data1_train[j-1]) )
    Price_closing_Stock1=data1_train[j-1]
    Price_closing_Stock2=data2_train[j-1]

    date_stock1=data1_date[j-1].strftime('%Y-%m-%d')
    #print(date_stock1)

    stocks1Value= Act_stocks1 * Price_closing_Stock1
    stocks2Value= Act_stocks2 * Price_closing_Stock2
    remaining_stock1=remaining_stock1-Act_stocks1
    remaining_stock2=remaining_stock2-Act_stocks2
    #print("J is:"+ str(j))



    Stock1_Port_value=remaining_stock1*Price_closing_Stock1
    Stock2_Port_value=remaining_stock2*Price_closing_Stock2
    Act_Bench_Open_cash=Act_Bench_Open_cash+stocks1Value+stocks2Value #Adding 10% sold value into open cash

    Total_Portfolio_value=Act_Bench_Open_cash+Stock1_Port_value+Stock2_Port_value
    Benchmark_Port_Value.append([date_stock1,Total_Portfolio_value])
        



#print ("total_Test_Benchmark_amount : " +  str(Total_Portfolio_value))

Training_Benchmark_Portfolio_Value= Total_Portfolio_value


print("Benchmark_Profit is  " + str(Training_Benchmark_Portfolio_Value) +"with Apple Stocks:  " + str(remaining_stock1) + 
      " and Amazon stocks:  "+ str(remaining_stock2) )


#Define arrays to store per episode values 
total_Prof=[]
total_stock1bal=[]
total_stock2bal=[]
total_open_cash=[]
total_port_value=[]
total_days_played=[]
# Out:
# Benchmark_Profit is  52655.37275with Apple Stocks:  6.0 and Amazon stocks:  9.0

# %% [markdown]
# ## Training

# %%
#Training run

import csv


for e in range(episode_count + 1):
    print("..........")
    print("Episode " + str(e) + "/" + str(episode_count))
    
    Bal_stock1=int(np.floor((start_balance/4)/data1_train[0]))
    Bal_stock2=int(np.floor((start_balance/4)/data2_train[0]))
    open_cash=start_balance/2
    
    datasize=training
    done=False
    total_profit = 0
    reward = 0
    
    #Initialize Agent
    agent = Agent(8)
    agent.inventory1 =[]
    agent.inventory2 =[]
    for i in range(Bal_stock1):
        agent.inventory1.append(data1_train[0])
    for i in range(Bal_stock2):
        agent.inventory2.append(data2_train[0]) 
    
    
    #Timestep delta to make sure that with time reward increases for taking action
    #timestep_delta=0
    
    #Running episode over all days in the datasize
    for t in range(datasize):
        #print("..........")
        #print(pd_data1_train.iloc[t,0])
        state_class_obj= State(data1_train, data2_train, Bal_stock1, Bal_stock2, open_cash,t)
        state_array_obj=state_class_obj.getState()
        action = agent.act(state_array_obj)
         
                   
        change_percent_stock1=(state_class_obj.Stock1Price-state_class_obj.fiveday_stock1)/state_class_obj.fiveday_stock1*100
        change_percent_stock2=(state_class_obj.Stock2Price-state_class_obj.fiveday_stock2)/state_class_obj.fiveday_stock2*100
        
        #print("change_percent_stock1:  "+str(change_percent_stock1))
        #print("change_percent_stock2:  "+str(change_percent_stock2))
        
        
        if action == 0:  #buy stock 1
            if state_class_obj.Stock1Price > state_class_obj.open_cash:
                '''
                print("Buy stock 1 when it did not have cash, so bankrupt, end of episode")
                reward=-reward_timedelta*10
                done = True
                '''
                #If agent is trying to buy when it has no cash but has stock1 and stock2 balance then, 
                #it should pick from other actions
                #if (state_class_obj.Stock1Blnc>1) and  (state_class_obj.Stock2Blnc>1):
                 #   action=random.sample([1, 2, 4, 5, 6],  1)  # Choose 1 elements from sell actions
                #else:    
                #print("Bankrupt")
                reward=-200000
                done = True
                #end episode
                     
            else:
                #print("In Buy stock 1")
                agent.inventory1.append(data1_train[t])
                Bal_stock1_t1= len(agent.inventory1)
                Bal_stock2_t1=len(agent.inventory2)
                open_cash_t1=state_class_obj.open_cash-state_class_obj.Stock1Price #Here we are buying 1 stock
                
                #needs to be reviewed
                
                if(state_class_obj.open_cash<500):
                    reward=-100000
                elif (abs(change_percent_stock1)<=2):
                    reward=-10000
                else:  
                    reward=-change_percent_stock1*100
                

               
                
        if action == 1:  #sell stock 1
            if state_class_obj.Stock1Blnc <1 :
               # print("sold stock 2 when it did not have stock 2, so bankrupt, end of episode")
                reward=-200000
                done = True
                #end episode
            else:
                #print("In sell stock 1")
                bought_price1=agent.inventory1.pop(0)
                Bal_stock1_t1= len(agent.inventory1)
                Bal_stock2_t1=len(agent.inventory2)
                open_cash_t1=state_class_obj.open_cash+state_class_obj.Stock1Price #State[0] is the price of stock 1. Here we are buying 1 stoc
          
                if(state_class_obj.Stock1Blnc<10):
                    reward=-100000
                elif (abs(change_percent_stock1)<=2):
                    reward=-10000
                else:
                    reward=change_percent_stock1*100 #State[0] is the price of stock 1. Here we are buying 1 stock
                
                #total_profit += data1_train[t] - bought_price1
            #print("reward for sell stock1 " + str(reward))
                
        


        
        if action == 2:             # Do nothing action    
                if (abs(change_percent_stock1)<=2) and (abs(change_percent_stock2)<=2):
                    reward=10000
                elif (state_class_obj.open_cash<0.1*start_balance):
                    reward=1000000
                elif (abs(change_percent_stock1)<=2) or (abs(change_percent_stock2)<=2):
                    reward=1000
                else:
                    reward=-100000
                
                Bal_stock1_t1= len(agent.inventory1)
                Bal_stock2_t1=len(agent.inventory2)
                open_cash_t1=open_cash
               # print("Do nothing")
        
        
        if action == 3:  #buy stock 2
            if state_class_obj.Stock2Price > state_class_obj.open_cash:
                '''
                print("Buy stock 2 when it did not have cash, so bankrupt, end of episode")
                reward=-reward_timedelta*10
                done = True
                
                '''
                #If agent is trying to buy when it has no cash but has stock1 and stock2 balance then, 
                #it should pick from other actions
                #if (state_class_obj.Stock1Blnc>1) and  (state_class_obj.Stock2Blnc>1):
                 #   action=random.sample([1, 2, 4, 5, 6],  1)  # Choose 1 elements from sell actions
                #else:    
                #print("Bankrupt")
                reward=-200000
                done = True
                     #end episode   
            else:
                #print("In Buy stock 2")
                agent.inventory2.append(data2_train[t])
                Bal_stock1_t1= len(agent.inventory1)
                Bal_stock2_t1=len(agent.inventory2)
                open_cash_t1=state_class_obj.open_cash-state_class_obj.Stock2Price
                
                if(state_class_obj.open_cash<5000):
                    reward=-100000
                elif (abs(change_percent_stock2)<=2):
                    reward=-10000
                else:
                    reward=-change_percent_stock2*100
 
        
        if action == 4:  #sell stock 2
            if state_class_obj.Stock2Blnc <1 :
                    #print("sold stock 2 when it did not have stock 2, so bankrupt, end of episode")
                    reward=-200000
                    done = True
                #end episode
            else:
                #print("In sell stock 2")
                bought_price2=agent.inventory2.pop(0)
                Bal_stock1_t1= len(agent.inventory1)
                Bal_stock2_t1=len(agent.inventory2)
                open_cash_t1=state_class_obj.open_cash+state_class_obj.Stock2Price
    
              
                if(state_class_obj.Stock2Blnc<10):
                    reward=-100000
                elif (abs(change_percent_stock2)<=2):
                    reward=-10000
                else:
                    reward=change_percent_stock2*100 
                
                
                total_profit += state_class_obj.Stock2Price - bought_price2

               # print("reward for selling stock2: " + str(reward))
            
        
        
        #print("reward:  "+str(reward))
        #if done!= False:done = True if t == datasize
        if t == datasize-1:
            #print("t==datasize")
            done=True
            next_state_class_obj=State(data1_train, data2_train, Bal_stock1_t1, Bal_stock2_t1, open_cash_t1,t)
            next_state_array_obj=next_state_class_obj.getState()
        else:
            next_state_class_obj=State(data1_train, data2_train, Bal_stock1_t1, Bal_stock2_t1, open_cash_t1,t+1)
            next_state_array_obj=next_state_class_obj.getState()
            
        agent.memory.append((state_array_obj, action, reward, next_state_array_obj, done))
        #print("Action is "+str(action)+" reward is" + str(reward))
         
        Bal_stock1=Bal_stock1_t1
        Bal_stock2= Bal_stock2_t1
        open_cash=open_cash_t1
        
        
      #  print("total_profit on day basis " + str(total_profit) +"on day"+str(t) + "stock 1 number: " + 
        #      str(len(agent.inventory1))+"/"+str(next_state_class_obj.Stock1Blnc)+" stock2 number:"+
         #         str(len(agent.inventory2)) +"/"+str(next_state_class_obj.Stock2Blnc)+
          #        "open cash: "+str(next_state_class_obj.open_cash))
        
       # print("doneAction" + str(done))
       # print("--------------------------------") 
       
        
        
        if done==True:
            #print("--------------------------------")
           # print("Total Profit: " + formatPrice(total_profit))
           # print("Total No. of days played: " + str(t)+ "  out of overall days:  " + str(datasize))
           # print("Total portfolio value: " + str(next_state_class_obj.portfolio_value)+ 
             #     "  stock 1 number: " + str(len(agent.inventory1))
            #      +"  stock 2 number: "+str(len(agent.inventory2))+"  open cash"+str(next_state_class_obj.open_cash))

            total_Prof.append(total_profit)
            total_stock1bal.append(len(agent.inventory1))
            total_stock2bal.append(len(agent.inventory2))
            total_open_cash.append(state_class_obj.open_cash)
            total_port_value.append(state_class_obj.portfolio_value)
            total_days_played.append(t)


            print("--------------------------------")
            state_class_obj.reset()
            break
           
          

        if len(agent.memory) > batch_size:
            agent.expReplay(batch_size)


    if e % 10 == 0:
        agent.model.save("models/model_ep" + str(e))
        

        
#print("Total Apple stocks in episodes"+ str(total_stock1bal))
#print("Total Amazon stocks in episodes"+ str(total_stock2bal))
#print("Total Open cash in episodes"+ str(total_open_cash))
#print("Total Portfolio value in episodes"+ str(total_port_value))
#print("Total Days in episodes"+ str(total_days_played))
#print("Benchmark_Profit is  " + str(int(Benchmark_Portfolio_Value)) +"   with Apple Stocks: " + str(Bench_Stock1_Bal) + 
    #  "   and Amazon stocks: "+ str(Bench_Stock2_Bal) )
# Out:
# ..........
# Episode 0/12
# 2022-03-11 17:19:12.851423: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-11 17:19:12.937180: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-11 17:19:12.937875: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-11 17:19:12.939048: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-03-11 17:19:12.940250: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-11 17:19:12.940961: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-11 17:19:12.941607: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-11 17:19:14.743844: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-11 17:19:14.744633: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-11 17:19:14.745584: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-11 17:19:14.746161: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15403 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# 2022-03-11 17:19:15.235837: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# --------------------------------
# 2022-03-11 17:19:57.095378: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# ..........
# Episode 1/12
# --------------------------------
# ..........
# Episode 2/12
# --------------------------------
# ..........
# Episode 3/12
# --------------------------------
# ..........
# Episode 4/12
# --------------------------------
# ..........
# Episode 5/12
# --------------------------------
# ..........
# Episode 6/12
# --------------------------------
# ..........
# Episode 7/12
# --------------------------------
# ..........
# Episode 8/12
# --------------------------------
# ..........
# Episode 9/12
# --------------------------------
# ..........
# Episode 10/12
# --------------------------------
# ..........
# Episode 11/12
# --------------------------------
# ..........
# Episode 12/12
# --------------------------------

# %%
print("Total Apple stocks in episodes"+ str(total_stock1bal))
print("Total Amazon stocks in episodes"+ str(total_stock2bal))
print("Total Open cash in episodes"+ str(total_open_cash))
print("Total Portfolio value in episodes"+ str(total_port_value))
print("Total Days in episodes"+ str(total_days_played))

print("Benchmark_Profit is  " + str(int(Training_Benchmark_Portfolio_Value)) +"   with remaining Apple Stocks: " + str(remaining_stock1) + 
      "   and remaining Amazon stocks: "+ str(remaining_stock2) )
# Out:
# Total Apple stocks in episodes[4448, 3458, 4465, 5704, 5707, 4467, 4456, 4474, 5689, 4494, 4339, 3241, 4461]
# Total Amazon stocks in episodes[45, 1277, 36, 1262, 1271, 37, 1274, 1485, 1258, 1395, 1119, 1275, 600]
# Total Open cash in episodes[44144.28191999996, 6505.683780000001, 44126.12804999998, 3274.4146000000023, 3040.9219100000064, 43924.71483, 4544.214860000003, 26.776660000006316, 3110.6396500000005, 16.10593000001262, 8763.772489999992, 6869.238280000007, 35463.12716999996]
# Total Portfolio value in episodes[51028.56191999996, 52993.55878, 50732.633049999975, 51969.2096, 52037.59191000001, 50566.76983, 52134.054860000004, 108416.63945999999, 51654.79965, 102004.58233000002, 51077.13248999999, 53029.348280000006, 60755.77216999997]
# Total Days in episodes[1499, 1499, 1499, 1499, 1499, 1499, 1499, 457, 1499, 460, 1499, 1499, 1499]
# Benchmark_Profit is  52655   with remaining Apple Stocks: 6.0   and remaining Amazon stocks: 9.0

# %% [markdown]
# ## Benchmark model for Actual Test Run

# %%
#Initialize state and set benchmarking model

import datetime

#print(df_data1)
total_Prof=[]
done=False

Act_datasize = test
batch_size = 64


#To be removed
#Sstart_balance=500

#Benchmark Model

# Take Opening price in a new variable
data1_test=pd_data1_test['Open']
data2_test=pd_data2_test['Open']

data1_date=pd_data1_test['Date']



Act_Bench_Stock1_Bal=int(np.floor((start_balance/4)/data1_test[0]))
Act_Bench_Stock2_Bal=int(np.floor((start_balance/4)/data2_test[0]))
Act_Bench_Open_cash=start_balance/2


### Program to calculate benchmark profit


#sell 10% of stock in 10 intervals

interval=int(Act_datasize/10)
Total_Stock1_Amount= 0
Total_Stock2_Amount= 0
stocks2Value = 0
stocks1Value = 0

Act_stocks1=np.floor(Act_Bench_Stock1_Bal /10)
Act_stocks2=np.floor(Act_Bench_Stock2_Bal /10)
#print(str(Act_stocks1))
#print(str(Act_stocks2))

remaining_stock1=Act_Bench_Stock1_Bal
remaining_stock2=Act_Bench_Stock2_Bal
ttl=0

Benchmark_Port_Value=[]


for j in range (interval,Act_datasize+1,interval):
    #print("closing prices : " + str(data1_test[j-1]) )
    Price_closing_Stock1=data1_test[j-1]
    Price_closing_Stock2=data2_test[j-1]
    date_stock1=data1_date[j-1].strftime('%Y-%m-%d')
    #print(date_stock1)
    #np.array(pd_data1_test['Date'])

    stocks1Value= Act_stocks1 * Price_closing_Stock1
    stocks2Value= Act_stocks2 * Price_closing_Stock2
    remaining_stock1=remaining_stock1-Act_stocks1
    remaining_stock2=remaining_stock2-Act_stocks2
    #print("J is:"+ str(j))



    Stock1_Port_value=remaining_stock1*Price_closing_Stock1
    Stock2_Port_value=remaining_stock2*Price_closing_Stock2
    Act_Bench_Open_cash=Act_Bench_Open_cash+stocks1Value+stocks2Value #Adding 10% sold value into open cash

    Total_Portfolio_value=Act_Bench_Open_cash+Stock1_Port_value+Stock2_Port_value
    Benchmark_Port_Value.append([date_stock1,Total_Portfolio_value])
        

#print ("total_Test_Benchmark_amount : " +  str(Total_Portfolio_value))

Test_Benchmark_Portfolio_Value= Total_Portfolio_value




print("Benchmark_Profit is" + str(Test_Benchmark_Portfolio_Value) +"with remaining Apple Stocks: " + str(remaining_stock1) + 
      " and remaining Amazon stocks: "+ str(remaining_stock2) )


#Define arrays to store per episode values 
total_Prof=[]
total_stock1bal=[]
total_stock2bal=[]
total_open_cash=[]
total_port_value=[]
total_days_played=[]


print(episode_count)
# Out:
# Benchmark_Profit is13725.1903with remaining Apple Stocks: 9.0 and remaining Amazon stocks: 6.0
# 12

# %% [markdown]
# ## Test

# %%
#Actual run

import csv
episode_count=0


#Define arrays to store per episode values 
total_Prof=[]
total_stock1bal=[]
total_stock2bal=[]
total_open_cash=[]
total_port_value=[]
total_days_played=[]

from keras.models import load_model

model_name='model_ep10'

model = load_model("models/" + model_name)

Act_Bench_Stock1_Bal=int(np.floor((start_balance/4)/data1_test[0]))
Act_Bench_Stock2_Bal=int(np.floor((start_balance/4)/data2_test[0]))
Act_Bench_Open_cash=start_balance/2

# %%
# prints formatted price
def formatPrice(n):
    return ("-$" if n < 0 else "$") + "{0:.2f}".format(abs(n))

#Actual run

import csv
episode_count=0


#Define arrays to store per episode values 
Act_total_Prof=[]
Act_total_stock1bal=[]
Act_total_stock2bal=[]
Act_total_open_cash=[]
Act_total_port_value=[]
Act_total_days_played=[]
actions_done_perday=[]
portfolio_value=[]

from keras.models import load_model

model_name='model_ep10' #ep50

initial_cash = 10000

model = load_model("models/" + model_name)


for e in range(1): #here we run only for 1 episode, as it is Test run
    Bal_stock1_t2=Act_Bench_Stock1_Bal
    Bal_stock2_t2=Act_Bench_Stock2_Bal
    done=False
    open_cash_t2= Act_Bench_Open_cash  
    total_profit = 0
    reward = 0
    
    #Initialize Agent
    agent_test = Agent(8, is_eval=True, model_name=model_name)
    #agent = Agent(8)

    agent_test.inventory1 =[]
    agent_test.inventory2 =[]
    for i in range(Bal_stock1_t2):
        agent_test.inventory1.append(data1_test[0])
    for i in range(Bal_stock2_t2):
        agent_test.inventory2.append(data2_test[0]) 
    
    
    #Timestep delta to make sure that with time reward increases for taking action
    timestep_delta=0
    
    #Running episode over all days in the datasize
    for t in range(Act_datasize):
        print("..........")
        
        print(pd_data1_test.iloc[t,0])
        state_class_obj= State(data1_test, data2_test, Bal_stock1_t2, Bal_stock2_t2, open_cash_t2,t)
        state_array_obj=state_class_obj.getState()
        action = agent_test.act(state_array_obj)
        
        print("Total portfolio value: " + str(state_class_obj.portfolio_value)+ 
                  "  stock 1 number: " + str(len(agent_test.inventory1))
                   +"  stock 2 number: "+str(len(agent_test.inventory2))+"  open cash"+str(state_class_obj.open_cash))


        
        #reward should be more as time goes further. We will remove reward_timedelta from actual reward 
        #reward_timedelta=(datasize-t)*timestep_delta
        
                   
        change_percent_stock1=(state_class_obj.Stock1Price-state_class_obj.fiveday_stock1)/state_class_obj.fiveday_stock1*100
        change_percent_stock2=(state_class_obj.Stock2Price-state_class_obj.fiveday_stock2)/state_class_obj.fiveday_stock2*100
        
        #print("change_percent_stock1:  "+str(change_percent_stock1))
        #print("change_percent_stock2:  "+str(change_percent_stock2))
        
        
        if action == 0:  #buy stock 1
            if state_class_obj.Stock1Price > state_class_obj.open_cash:
                '''
                print("Buy stock 1 when it did not have cash, so bankrupt, end of episode")
                reward=-reward_timedelta*10
                done = True
                '''
                #If agent is trying to buy when it has no cash but has stock1 and stock2 balance then, 
                #it should pick from other actions
                #if (state_class_obj.Stock1Blnc>1) and  (state_class_obj.Stock2Blnc>1):
                 #   action=random.sample([1, 2, 4, 5, 6],  1)  # Choose 1 elements from sell actions
                #else:    
                #print("Bankrupt")
              
                done = True
                #end episode
                     
            else:
                #print("In Buy stock 1")
                agent_test.inventory1.append(data1_test[t])
                Bal_stock1_t2= len(agent_test.inventory1)
                Bal_stock2_t2=len(agent_test.inventory2)
                open_cash_t2=state_class_obj.open_cash-state_class_obj.Stock1Price #Here we are buying 1 stock
                
                
               
                
        if action == 1:  #sell stock 1
            if state_class_obj.Stock1Blnc <1 :
               # print("sold stock 2 when it did not have stock 2, so bankrupt, end of episode")
                
                done = True
                #end episode
            else:
                #print("In sell stock 1")
                agent_test.inventory1.pop(0)

                Bal_stock1_t2= len(agent_test.inventory1)
                Bal_stock2_t2=len(agent_test.inventory2)
                open_cash_t2=state_class_obj.open_cash+state_class_obj.Stock1Price #State[0] is the price of stock 1. Here we are buying 1 stoc
          
                 
        


        
        if action == 2:             # Do nothing action    
                Bal_stock1_t2= len(agent_test.inventory1)
                Bal_stock2_t2=len(agent_test.inventory2)
               # print("Do nothing")
        
        
        if action == 3:  #buy stock 2
            if state_class_obj.Stock2Price > state_class_obj.open_cash:
                '''
                print("Buy stock 2 when it did not have cash, so bankrupt, end of episode")
                reward=-reward_timedelta*10
                done = True
                
                '''
                #If agent is trying to buy when it has no cash but has stock1 and stock2 balance then, 
                #it should pick from other actions
                #if (state_class_obj.Stock1Blnc>1) and  (state_class_obj.Stock2Blnc>1):
                 #   action=random.sample([1, 2, 4, 5, 6],  1)  # Choose 1 elements from sell actions
                #else:    
                #print("Bankrupt")

                done = True
                     #end episode   
            else:
                #print("In Buy stock 2")
                agent.inventory2.append(data2_test[t])
                Bal_stock1_t2= len(agent_test.inventory1)
                Bal_stock2_t2=len(agent_test.inventory2)
                open_cash_t2=state_class_obj.open_cash-state_class_obj.Stock2Price
                
              
        
        if action == 4:  #sell stock 2
            if state_class_obj.Stock2Blnc <1 :
                    #print("sold stock 2 when it did not have stock 2, so bankrupt, end of episode")
                    done = True
                #end episode
            else:
                #print("In sell stock 2")
                agent_test.inventory2.pop(0)
                Bal_stock1_t2= len(agent_test.inventory1)
                Bal_stock2_t2=len(agent_test.inventory2)
                open_cash_t2=state_class_obj.open_cash+state_class_obj.Stock2Price
    

               # print("reward for selling stock2: " + str(reward))
            
        
        
        #print("reward:  "+str(reward))
        #if done!= False:done = True if t == datasize
        if t == Act_datasize-1:
            #print("t==datasize")
            done=True
            next_state_class_obj=State(data1_test, data2_test, Bal_stock1_t2, Bal_stock2_t2, open_cash_t2,t)
            next_state_array_obj=next_state_class_obj.getState()
        else:
            #print("t!=datasize"+str(open_cash_t2))
            next_state_class_obj=State(data1_test, data2_test, Bal_stock1_t2, Bal_stock2_t2, open_cash_t2,t+1)
            next_state_array_obj=next_state_class_obj.getState()
            
        #print("Action is "+str(action)+" reward is" + str(reward))


       
        
        actions_done_perday.append(action)
        portfolio_value.append(next_state_class_obj.portfolio_value)

        if done==True:
            print("--------------------------------")
            print("Total Profit: " + formatPrice(next_state_class_obj.portfolio_value - initial_cash)) # total_profit
            print("Total No. of days played: " + str(t)+ "  out of overall days:  " + str(Act_datasize))
            print("Total portfolio value: " + str(next_state_class_obj.portfolio_value)+ 
                  "  stock 1 number: " + str(len(agent_test.inventory1))
                   +"  stock 2 number: "+str(len(agent_test.inventory2))+"  open cash"+str(next_state_class_obj.open_cash))

            Act_total_Prof.append(total_profit)
            Act_total_stock1bal.append(len(agent_test.inventory1))
            Act_total_stock2bal.append(len(agent_test.inventory2))
            Act_total_open_cash.append(state_class_obj.open_cash)
            Act_total_port_value.append(state_class_obj.portfolio_value)
            Act_total_days_played.append(t)


            print("--------------------------------")
            state_class_obj.reset()
            break
# Out:
# ..........
# 2003-05-15 00:00:00
# Total portfolio value: 9980.548999999999  stock 1 number: 2099  stock 2 number: 76  open cash5000.0
# ..........
# 2003-05-16 00:00:00
# Total portfolio value: 9968.149000000001  stock 1 number: 2100  stock 2 number: 76  open cash4998.809
# ..........
# 2003-05-19 00:00:00
# Total portfolio value: 9976.9163  stock 1 number: 2101  stock 2 number: 76  open cash4997.6192
# ..........
# 2003-05-20 00:00:00
# Total portfolio value: 9830.999899999999  stock 1 number: 2102  stock 2 number: 76  open cash4996.4321
# ..........
# 2003-05-21 00:00:00
# Total portfolio value: 9782.0187  stock 1 number: 2103  stock 2 number: 76  open cash4995.2732
# ..........
# 2003-05-22 00:00:00
# Total portfolio value: 9818.7395  stock 1 number: 2104  stock 2 number: 76  open cash4994.1347
# ..........
# 2003-05-23 00:00:00
# Total portfolio value: 9959.172  stock 1 number: 2105  stock 2 number: 76  open cash4992.9884999999995
# ..........
# 2003-05-27 00:00:00
# Total portfolio value: 9887.732399999999  stock 1 number: 2106  stock 2 number: 76  open cash4991.8218
# ..........
# 2003-05-28 00:00:00
# Total portfolio value: 10137.2932  stock 1 number: 2107  stock 2 number: 76  open cash4990.6717
# ..........
# 2003-05-29 00:00:00
# Total portfolio value: 10108.330399999999  stock 1 number: 2108  stock 2 number: 76  open cash4989.4872
# ..........
# 2003-05-30 00:00:00
# Total portfolio value: 10141.327699999998  stock 1 number: 2109  stock 2 number: 76  open cash4988.3168
# ..........
# 2003-06-02 00:00:00
# Total portfolio value: 10206.4357  stock 1 number: 2110  stock 2 number: 76  open cash4987.1567
# ..........
# 2003-06-03 00:00:00
# Total portfolio value: 9981.3115  stock 1 number: 2111  stock 2 number: 76  open cash4985.997799999999
# ..........
# 2003-06-04 00:00:00
# Total portfolio value: 9984.5547  stock 1 number: 2112  stock 2 number: 76  open cash4984.8811
# ..........
# 2003-06-05 00:00:00
# Total portfolio value: 10015.520400000001  stock 1 number: 2113  stock 2 number: 76  open cash4983.7733
# ..........
# 2003-06-06 00:00:00
# Total portfolio value: 10122.7778  stock 1 number: 2114  stock 2 number: 76  open cash4982.6566
# ..........
# 2003-06-09 00:00:00
# Total portfolio value: 9895.381300000001  stock 1 number: 2115  stock 2 number: 76  open cash4981.5208
# ..........
# 2003-06-10 00:00:00
# Total portfolio value: 9855.6797  stock 1 number: 2116  stock 2 number: 76  open cash4980.4361
# ..........
# 2003-06-11 00:00:00
# Total portfolio value: 9884.2698  stock 1 number: 2117  stock 2 number: 76  open cash4979.354
# ..........
# 2003-06-12 00:00:00
# Total portfolio value: 10042.7476  stock 1 number: 2118  stock 2 number: 76  open cash4978.256600000001
# ..........
# 2003-06-13 00:00:00
# Total portfolio value: 10077.047  stock 1 number: 2119  stock 2 number: 76  open cash4977.132100000001
# ..........
# 2003-06-16 00:00:00
# Total portfolio value: 9992.767  stock 1 number: 2120  stock 2 number: 76  open cash4975.995000000001
# ..........
# 2003-06-17 00:00:00
# Total portfolio value: 10207.2674  stock 1 number: 2121  stock 2 number: 76  open cash4974.867900000001
# ..........
# 2003-06-18 00:00:00
# Total portfolio value: 10177.346000000001  stock 1 number: 2122  stock 2 number: 76  open cash4973.688400000001
# ..........
# 2003-06-19 00:00:00
# Total portfolio value: 10324.9784  stock 1 number: 2123  stock 2 number: 76  open cash4972.507600000001
# ..........
# 2003-06-20 00:00:00
# Total portfolio value: 10324.9784  stock 1 number: 2124  stock 2 number: 76  open cash4971.268000000001
# ..........
# 2003-06-23 00:00:00
# Total portfolio value: 10259.780900000002  stock 1 number: 2125  stock 2 number: 76  open cash4970.028400000001
# ..........
# 2003-06-24 00:00:00
# Total portfolio value: 10305.6957  stock 1 number: 2126  stock 2 number: 76  open cash4968.792300000001
# ..........
# 2003-06-25 00:00:00
# Total portfolio value: 10208.276600000001  stock 1 number: 2127  stock 2 number: 76  open cash4967.546400000001
# ..........
# 2003-06-26 00:00:00
# Total portfolio value: 10190.371000000003  stock 1 number: 2128  stock 2 number: 76  open cash4966.3438000000015
# ..........
# 2003-06-27 00:00:00
# Total portfolio value: 10385.243300000002  stock 1 number: 2129  stock 2 number: 76  open cash4965.146400000001
# ..........
# 2003-06-30 00:00:00
# Total portfolio value: 10295.696300000001  stock 1 number: 2130  stock 2 number: 76  open cash4963.910300000001
# ..........
# 2003-07-01 00:00:00
# Total portfolio value: 10312.12  stock 1 number: 2131  stock 2 number: 76  open cash4962.714100000001
# ..........
# 2003-07-02 00:00:00
# Total portfolio value: 10418.439600000002  stock 1 number: 2132  stock 2 number: 76  open cash4961.505200000001
# ..........
# 2003-07-03 00:00:00
# Total portfolio value: 10369.027100000003  stock 1 number: 2133  stock 2 number: 76  open cash4960.286000000002
# ..........
# 2003-07-07 00:00:00
# Total portfolio value: 10501.944900000002  stock 1 number: 2134  stock 2 number: 76  open cash4959.069300000002
# ..........
# 2003-07-08 00:00:00
# Total portfolio value: 10572.132400000002  stock 1 number: 2135  stock 2 number: 76  open cash4957.835900000002
# ..........
# 2003-07-09 00:00:00
# Total portfolio value: 10802.4644  stock 1 number: 2136  stock 2 number: 76  open cash4956.586000000002
# ..........
# 2003-07-10 00:00:00
# Total portfolio value: 10648.812600000001  stock 1 number: 2137  stock 2 number: 76  open cash4955.291600000002
# ..........
# 2003-07-11 00:00:00
# Total portfolio value: 10556.133000000002  stock 1 number: 2138  stock 2 number: 76  open cash4954.018600000002
# ..........
# 2003-07-14 00:00:00
# Total portfolio value: 10620.743900000001  stock 1 number: 2139  stock 2 number: 76  open cash4952.7598000000025
# ..........
# 2003-07-15 00:00:00
# Total portfolio value: 10705.103900000002  stock 1 number: 2140  stock 2 number: 76  open cash4951.477900000003
# ..........
# 2003-07-16 00:00:00
# Total portfolio value: 10565.313300000003  stock 1 number: 2141  stock 2 number: 76  open cash4950.196000000003
# ..........
# 2003-07-17 00:00:00
# Total portfolio value: 10542.589300000003  stock 1 number: 2142  stock 2 number: 76  open cash4948.940700000003
# ..........
# 2003-07-18 00:00:00
# Total portfolio value: 10575.515700000004  stock 1 number: 2143  stock 2 number: 76  open cash4947.647400000003
# ..........
# 2003-07-21 00:00:00
# Total portfolio value: 10426.141300000003  stock 1 number: 2144  stock 2 number: 76  open cash4946.309300000003
# ..........
# 2003-07-22 00:00:00
# Total portfolio value: 10525.190800000004  stock 1 number: 2145  stock 2 number: 76  open cash4944.983800000003
# ..........
# 2003-07-23 00:00:00
# Total portfolio value: 10689.789400000003  stock 1 number: 2146  stock 2 number: 76  open cash4943.647200000003
# ..........
# 2003-07-24 00:00:00
# Total portfolio value: 10954.330200000004  stock 1 number: 2147  stock 2 number: 76  open cash4942.306500000003
# ..........
# 2003-07-25 00:00:00
# Total portfolio value: 10845.709400000003  stock 1 number: 2148  stock 2 number: 76  open cash4940.959400000003
# ..........
# 2003-07-28 00:00:00
# Total portfolio value: 11051.850000000002  stock 1 number: 2149  stock 2 number: 76  open cash4939.6519000000035
# ..........
# 2003-07-29 00:00:00
# Total portfolio value: 11017.825000000004  stock 1 number: 2150  stock 2 number: 76  open cash4938.275000000003
# ..........
# 2003-07-30 00:00:00
# Total portfolio value: 10923.871000000003  stock 1 number: 2151  stock 2 number: 76  open cash4936.9316000000035
# ..........
# 2003-07-31 00:00:00
# Total portfolio value: 10936.488600000004  stock 1 number: 2152  stock 2 number: 76  open cash4935.602200000004
# ..........
# 2003-08-01 00:00:00
# Total portfolio value: 10976.573100000005  stock 1 number: 2153  stock 2 number: 76  open cash4934.274000000004
# ..........
# 2003-08-04 00:00:00
# Total portfolio value: 10782.854700000004  stock 1 number: 2154  stock 2 number: 76  open cash4932.929300000004
# ..........
# 2003-08-05 00:00:00
# Total portfolio value: 10861.032200000005  stock 1 number: 2155  stock 2 number: 76  open cash4931.6142000000045
# ..........
# 2003-08-06 00:00:00
# Total portfolio value: 10634.533000000005  stock 1 number: 2156  stock 2 number: 76  open cash4930.246600000005
# ..........
# 2003-08-07 00:00:00
# Total portfolio value: 10619.410200000006  stock 1 number: 2157  stock 2 number: 76  open cash4928.962200000005
# ..........
# 2003-08-08 00:00:00
# Total portfolio value: 10679.355800000005  stock 1 number: 2158  stock 2 number: 76  open cash4927.698200000005
# ..........
# 2003-08-11 00:00:00
# Total portfolio value: 10629.637900000005  stock 1 number: 2159  stock 2 number: 76  open cash4926.4110000000055
# ..........
# 2003-08-12 00:00:00
# Total portfolio value: 10618.389900000006  stock 1 number: 2160  stock 2 number: 76  open cash4925.141900000005
# ..........
# 2003-08-13 00:00:00
# Total portfolio value: 10731.020300000006  stock 1 number: 2161  stock 2 number: 76  open cash4923.876600000005
# ..........
# 2003-08-14 00:00:00
# Total portfolio value: 10755.017700000004  stock 1 number: 2162  stock 2 number: 76  open cash4922.604900000005
# ..........
# 2003-08-15 00:00:00
# Total portfolio value: 10743.104500000005  stock 1 number: 2163  stock 2 number: 76  open cash4921.310500000005
# ..........
# 2003-08-18 00:00:00
# Total portfolio value: 10748.471300000005  stock 1 number: 2164  stock 2 number: 76  open cash4920.032500000005
# ..........
# 2003-08-19 00:00:00
# Total portfolio value: 11046.285800000005  stock 1 number: 2165  stock 2 number: 76  open cash4918.760800000005
# ..........
# 2003-08-20 00:00:00
# Total portfolio value: 10988.921000000006  stock 1 number: 2166  stock 2 number: 76  open cash4917.455800000004
# ..........
# 2003-08-21 00:00:00
# Total portfolio value: 11196.049300000004  stock 1 number: 2167  stock 2 number: 76  open cash4916.163600000004
# ..........
# 2003-08-22 00:00:00
# Total portfolio value: 11464.704500000003  stock 1 number: 2168  stock 2 number: 76  open cash4914.816500000004
# ..........
# 2003-08-25 00:00:00
# Total portfolio value: 11208.308800000006  stock 1 number: 2169  stock 2 number: 76  open cash4913.420500000005
# ..........
# 2003-08-26 00:00:00
# Total portfolio value: 11266.287800000006  stock 1 number: 2170  stock 2 number: 76  open cash4912.089800000004
# ..........
# 2003-08-27 00:00:00
# Total portfolio value: 11297.117800000005  stock 1 number: 2171  stock 2 number: 76  open cash4910.760400000005
# ..........
# 2003-08-28 00:00:00
# Total portfolio value: 11361.081000000006  stock 1 number: 2172  stock 2 number: 76  open cash4909.421000000005
# ..........
# 2003-08-29 00:00:00
# Total portfolio value: 11479.512800000004  stock 1 number: 2173  stock 2 number: 76  open cash4908.056000000005
# ..........
# 2003-09-02 00:00:00
# Total portfolio value: 11596.411000000007  stock 1 number: 2174  stock 2 number: 76  open cash4906.634400000005
# ..........
# 2003-09-03 00:00:00
# Total portfolio value: 11696.328500000007  stock 1 number: 2175  stock 2 number: 76  open cash4905.183500000006
# ..........
# 2003-09-04 00:00:00
# Total portfolio value: 11641.714100000007  stock 1 number: 2176  stock 2 number: 76  open cash4903.723700000006
# ..........
# 2003-09-05 00:00:00
# Total portfolio value: 11639.717400000005  stock 1 number: 2177  stock 2 number: 76  open cash4902.240800000006
# ..........
# 2003-09-08 00:00:00
# Total portfolio value: 11569.362600000008  stock 1 number: 2178  stock 2 number: 76  open cash4900.785000000006
# ..........
# 2003-09-09 00:00:00
# Total portfolio value: 11637.794400000006  stock 1 number: 2179  stock 2 number: 76  open cash4899.345800000006
# ..........
# 2003-09-10 00:00:00
# Total portfolio value: 11518.636400000007  stock 1 number: 2180  stock 2 number: 76  open cash4897.902400000006
# ..........
# 2003-09-11 00:00:00
# Total portfolio value: 11514.076400000005  stock 1 number: 2181  stock 2 number: 76  open cash4896.478100000007
# ..........
# 2003-09-12 00:00:00
# Total portfolio value: 11450.316000000006  stock 1 number: 2182  stock 2 number: 76  open cash4895.053800000007
# ..........
# 2003-09-15 00:00:00
# Total portfolio value: 11593.948700000006  stock 1 number: 2183  stock 2 number: 76  open cash4893.611700000007
# ..........
# 2003-09-16 00:00:00
# Total portfolio value: 11450.146300000008  stock 1 number: 2184  stock 2 number: 76  open cash4892.1327000000065
# ..........
# 2003-09-17 00:00:00
# Total portfolio value: 11533.119300000006  stock 1 number: 2185  stock 2 number: 76  open cash4890.709800000007
# ..........
# 2003-09-18 00:00:00
# Total portfolio value: 11490.845700000007  stock 1 number: 2186  stock 2 number: 76  open cash4889.277100000007
# ..........
# 2003-09-19 00:00:00
# Total portfolio value: 11730.155700000007  stock 1 number: 2187  stock 2 number: 76  open cash4887.862000000006
# ..........
# 2003-09-22 00:00:00
# Total portfolio value: 11609.874500000005  stock 1 number: 2188  stock 2 number: 76  open cash4886.396900000006
# ..........
# 2003-09-23 00:00:00
# Total portfolio value: 11573.751100000007  stock 1 number: 2189  stock 2 number: 76  open cash4884.9767000000065
# ..........
# 2003-09-24 00:00:00
# Total portfolio value: 11826.318100000008  stock 1 number: 2190  stock 2 number: 76  open cash4883.567100000007
# ..........
# 2003-09-25 00:00:00
# Total portfolio value: 11649.867500000008  stock 1 number: 2191  stock 2 number: 76  open cash4882.144200000007
# ..........
# 2003-09-26 00:00:00
# Total portfolio value: 11522.33950000001  stock 1 number: 2192  stock 2 number: 76  open cash4880.777900000007
# ..........
# 2003-09-29 00:00:00
# Total portfolio value: 11611.048900000007  stock 1 number: 2193  stock 2 number: 76  open cash4879.4781000000075
# ..........
# 2003-09-30 00:00:00
# Total portfolio value: 11613.183100000007  stock 1 number: 2194  stock 2 number: 76  open cash4878.102500000007
# ..........
# 2003-10-01 00:00:00
# Total portfolio value: 11465.418100000006  stock 1 number: 2195  stock 2 number: 76  open cash4876.752600000007
# ..........
# 2003-10-02 00:00:00
# Total portfolio value: 11519.937700000006  stock 1 number: 2196  stock 2 number: 76  open cash4875.425700000007
# ..........
# 2003-10-03 00:00:00
# Total portfolio value: 11711.423500000006  stock 1 number: 2197  stock 2 number: 76  open cash4874.093700000007
# ..........
# 2003-10-06 00:00:00
# Total portfolio value: 11942.994500000006  stock 1 number: 2198  stock 2 number: 76  open cash4872.750300000007
# ..........
# 2003-10-07 00:00:00
# Total portfolio value: 12081.010100000007  stock 1 number: 2199  stock 2 number: 76  open cash4871.362400000007
# ..........
# 2003-10-08 00:00:00
# Total portfolio value: 12357.430100000007  stock 1 number: 2200  stock 2 number: 76  open cash4869.950100000007
# ..........
# 2003-10-09 00:00:00
# Total portfolio value: 12388.195100000008  stock 1 number: 2201  stock 2 number: 76  open cash4868.4619000000075
# ..........
# 2003-10-10 00:00:00
# Total portfolio value: 12577.898300000008  stock 1 number: 2202  stock 2 number: 76  open cash4866.968700000008
# ..........
# 2003-10-13 00:00:00
# Total portfolio value: 12617.684200000007  stock 1 number: 2203  stock 2 number: 76  open cash4865.463900000008
# ..........
# 2003-10-14 00:00:00
# Total portfolio value: 12712.053400000008  stock 1 number: 2204  stock 2 number: 76  open cash4863.943800000008
# ..........
# 2003-10-15 00:00:00
# Total portfolio value: 12961.94540000001  stock 1 number: 2205  stock 2 number: 76  open cash4862.3864000000085
# ..........
# 2003-10-16 00:00:00
# Total portfolio value: 12642.898600000008  stock 1 number: 2206  stock 2 number: 76  open cash4860.794600000008
# ..........
# 2003-10-17 00:00:00
# Total portfolio value: 12669.72890000001  stock 1 number: 2207  stock 2 number: 76  open cash4859.270600000008
# ..........
# 2003-10-20 00:00:00
# Total portfolio value: 12580.19290000001  stock 1 number: 2208  stock 2 number: 76  open cash4857.773700000008
# ..........
# 2003-10-21 00:00:00
# Total portfolio value: 12691.413400000009  stock 1 number: 2209  stock 2 number: 76  open cash4856.326300000008
# ..........
# 2003-10-22 00:00:00
# Total portfolio value: 12395.91840000001  stock 1 number: 2210  stock 2 number: 76  open cash4854.834400000008
# ..........
# 2003-10-23 00:00:00
# Total portfolio value: 12098.603800000008  stock 1 number: 2211  stock 2 number: 76  open cash4853.350000000008
# ..........
# 2003-10-24 00:00:00
# Total portfolio value: 12193.59180000001  stock 1 number: 2212  stock 2 number: 76  open cash4851.894200000008
# ..........
# 2003-10-27 00:00:00
# Total portfolio value: 12217.99300000001  stock 1 number: 2213  stock 2 number: 76  open cash4850.449400000008
# ..........
# 2003-10-28 00:00:00
# Total portfolio value: 12242.219400000007  stock 1 number: 2214  stock 2 number: 76  open cash4848.992200000008
# ..........
# 2003-10-29 00:00:00
# Total portfolio value: 12488.737400000007  stock 1 number: 2215  stock 2 number: 76  open cash4847.547400000008
# ..........
# 2003-10-30 00:00:00
# Total portfolio value: 12611.109400000007  stock 1 number: 2216  stock 2 number: 76  open cash4846.041400000007
# ..........
# 2003-10-31 00:00:00
# Total portfolio value: 12400.448200000006  stock 1 number: 2217  stock 2 number: 76  open cash4844.505900000007
# ..........
# 2003-11-03 00:00:00
# Total portfolio value: 12248.533800000008  stock 1 number: 2218  stock 2 number: 76  open cash4843.014000000007
# ..........
# 2003-11-04 00:00:00
# Total portfolio value: 12429.991100000007  stock 1 number: 2219  stock 2 number: 76  open cash4841.552900000007
# ..........
# 2003-11-05 00:00:00
# Total portfolio value: 12349.597100000008  stock 1 number: 2220  stock 2 number: 76  open cash4840.075100000007
# ..........
# 2003-11-06 00:00:00
# Total portfolio value: 12416.157800000008  stock 1 number: 2221  stock 2 number: 76  open cash4838.614000000007
# ..........
# 2003-11-07 00:00:00
# Total portfolio value: 12364.509400000006  stock 1 number: 2222  stock 2 number: 76  open cash4837.1462000000065
# ..........
# 2003-11-10 00:00:00
# Total portfolio value: 12129.422400000007  stock 1 number: 2223  stock 2 number: 76  open cash4835.6606000000065
# ..........
# 2003-11-11 00:00:00
# Total portfolio value: 11893.224000000006  stock 1 number: 2224  stock 2 number: 76  open cash4834.2240000000065
# ..........
# 2003-11-12 00:00:00
# Total portfolio value: 11888.851500000008  stock 1 number: 2225  stock 2 number: 76  open cash4832.821500000006
# ..........
# 2003-11-13 00:00:00
# Total portfolio value: 12120.330300000005  stock 1 number: 2226  stock 2 number: 76  open cash4831.445900000006
# ..........
# 2003-11-14 00:00:00
# Total portfolio value: 12171.794900000006  stock 1 number: 2227  stock 2 number: 76  open cash4830.016500000006
# ..........
# 2003-11-17 00:00:00
# Total portfolio value: 11821.510100000007  stock 1 number: 2228  stock 2 number: 76  open cash4828.577300000006
# ..........
# 2003-11-18 00:00:00
# Total portfolio value: 11711.232000000007  stock 1 number: 2229  stock 2 number: 76  open cash4827.209700000007
# ..........
# 2003-11-19 00:00:00
# Total portfolio value: 11463.383000000007  stock 1 number: 2230  stock 2 number: 76  open cash4825.851000000007
# ..........
# 2003-11-20 00:00:00
# Total portfolio value: 11427.877800000006  stock 1 number: 2231  stock 2 number: 76  open cash4824.534600000007
# ..........
# 2003-11-21 00:00:00
# Total portfolio value: 11454.427400000008  stock 1 number: 2232  stock 2 number: 76  open cash4823.2474000000075
# ..........
# 2003-11-24 00:00:00
# Total portfolio value: 11445.060700000007  stock 1 number: 2233  stock 2 number: 76  open cash4821.944900000008
# ..........
# 2003-11-25 00:00:00
# Total portfolio value: 11761.248900000008  stock 1 number: 2234  stock 2 number: 76  open cash4820.6323000000075
# ..........
# 2003-11-26 00:00:00
# Total portfolio value: 11825.005900000007  stock 1 number: 2235  stock 2 number: 76  open cash4819.272400000007
# ..........
# 2003-11-28 00:00:00
# Total portfolio value: 11800.722700000006  stock 1 number: 2236  stock 2 number: 76  open cash4817.934300000007
# ..........
# 2003-12-01 00:00:00
# Total portfolio value: 11964.470100000006  stock 1 number: 2237  stock 2 number: 76  open cash4816.607400000007
# ..........
# 2003-12-02 00:00:00
# Total portfolio value: 12052.190500000008  stock 1 number: 2238  stock 2 number: 76  open cash4815.260300000007
# ..........
# 2003-12-03 00:00:00
# Total portfolio value: 12014.177900000008  stock 1 number: 2239  stock 2 number: 76  open cash4813.877400000008
# ..........
# 2003-12-04 00:00:00
# Total portfolio value: 11740.201900000007  stock 1 number: 2240  stock 2 number: 76  open cash4812.497900000008
# ..........
# 2003-12-05 00:00:00
# Total portfolio value: 11701.03290000001  stock 1 number: 2241  stock 2 number: 76  open cash4811.150800000008
# ..........
# 2003-12-08 00:00:00
# Total portfolio value: 11711.042100000008  stock 1 number: 2242  stock 2 number: 76  open cash4809.812700000008
# ..........
# 2003-12-09 00:00:00
# Total portfolio value: 11739.582900000009  stock 1 number: 2243  stock 2 number: 76  open cash4808.482000000007
# ..........
# 2003-12-10 00:00:00
# Total portfolio value: 11502.497300000006  stock 1 number: 2244  stock 2 number: 76  open cash4807.125700000007
# ..........
# 2003-12-11 00:00:00
# Total portfolio value: 11458.872300000006  stock 1 number: 2245  stock 2 number: 76  open cash4805.816800000007
# ..........
# 2003-12-12 00:00:00
# Total portfolio value: 11731.110900000007  stock 1 number: 2246  stock 2 number: 76  open cash4804.520900000007
# ..........
# 2003-12-15 00:00:00
# Total portfolio value: 11849.929100000007  stock 1 number: 2247  stock 2 number: 76  open cash4803.155900000007
# ..........
# 2003-12-16 00:00:00
# Total portfolio value: 11478.718700000005  stock 1 number: 2248  stock 2 number: 76  open cash4801.780300000007
# ..........
# 2003-12-17 00:00:00
# Total portfolio value: 11452.196100000006  stock 1 number: 2249  stock 2 number: 76  open cash4800.487000000006
# ..........
# 2003-12-18 00:00:00
# Total portfolio value: 11284.736100000006  stock 1 number: 2250  stock 2 number: 76  open cash4799.201100000007
# ..........
# 2003-12-19 00:00:00
# Total portfolio value: 11417.945100000006  stock 1 number: 2251  stock 2 number: 76  open cash4797.926800000007
# ..........
# 2003-12-22 00:00:00
# Total portfolio value: 11351.003500000006  stock 1 number: 2252  stock 2 number: 76  open cash4796.633500000006
# ..........
# 2003-12-23 00:00:00
# Total portfolio value: 11470.372200000007  stock 1 number: 2253  stock 2 number: 76  open cash4795.376000000007
# ..........
# 2003-12-24 00:00:00
# Total portfolio value: 11614.801000000007  stock 1 number: 2254  stock 2 number: 76  open cash4794.100600000006
# ..........
# 2003-12-26 00:00:00
# Total portfolio value: 11847.321500000005  stock 1 number: 2255  stock 2 number: 76  open cash4792.838000000006
# ..........
# 2003-12-29 00:00:00
# Total portfolio value: 11901.260700000006  stock 1 number: 2256  stock 2 number: 76  open cash4791.534300000006
# ..........
# 2003-12-30 00:00:00
# Total portfolio value: 11893.044000000005  stock 1 number: 2257  stock 2 number: 76  open cash4790.194900000006
# ..........
# 2003-12-31 00:00:00
# Total portfolio value: 11891.199400000005  stock 1 number: 2258  stock 2 number: 76  open cash4788.8386000000055
# ..........
# 2004-01-02 00:00:00
# Total portfolio value: 11916.232300000007  stock 1 number: 2259  stock 2 number: 76  open cash4787.471000000006
# ..........
# 2004-01-05 00:00:00
# Total portfolio value: 11836.920300000005  stock 1 number: 2260  stock 2 number: 76  open cash4786.090300000006
# ..........
# 2004-01-06 00:00:00
# Total portfolio value: 12041.421100000007  stock 1 number: 2261  stock 2 number: 76  open cash4784.718800000006
# ..........
# 2004-01-07 00:00:00
# Total portfolio value: 11949.930700000006  stock 1 number: 2262  stock 2 number: 76  open cash4783.294500000006
# ..........
# 2004-01-08 00:00:00
# Total portfolio value: 12050.130600000008  stock 1 number: 2263  stock 2 number: 76  open cash4781.879400000006
# ..........
# 2004-01-09 00:00:00
# Total portfolio value: 11932.221800000007  stock 1 number: 2264  stock 2 number: 76  open cash4780.417000000006
# ..........
# 2004-01-12 00:00:00
# Total portfolio value: 12063.097300000005  stock 1 number: 2265  stock 2 number: 76  open cash4778.928800000006
# ..........
# 2004-01-13 00:00:00
# Total portfolio value: 12364.044900000006  stock 1 number: 2266  stock 2 number: 76  open cash4777.445900000006
# ..........
# 2004-01-14 00:00:00
# Total portfolio value: 12468.718500000006  stock 1 number: 2267  stock 2 number: 76  open cash4775.864400000006
# ..........
# 2004-01-15 00:00:00
# Total portfolio value: 12262.752500000006  stock 1 number: 2268  stock 2 number: 76  open cash4774.302100000006
# ..........
# 2004-01-16 00:00:00
# Total portfolio value: 12388.097500000005  stock 1 number: 2269  stock 2 number: 76  open cash4772.834300000006
# ..........
# 2004-01-20 00:00:00
# Total portfolio value: 12290.948500000006  stock 1 number: 2270  stock 2 number: 76  open cash4771.361500000006
# ..........
# 2004-01-21 00:00:00
# Total portfolio value: 12337.980800000005  stock 1 number: 2271  stock 2 number: 76  open cash4769.909400000006
# ..........
# 2004-01-22 00:00:00
# Total portfolio value: 12368.601600000005  stock 1 number: 2272  stock 2 number: 76  open cash4768.456000000006
# ..........
# 2004-01-23 00:00:00
# Total portfolio value: 12344.045100000007  stock 1 number: 2273  stock 2 number: 76  open cash4767.011200000005
# ..........
# 2004-01-26 00:00:00
# Total portfolio value: 12352.931500000006  stock 1 number: 2274  stock 2 number: 76  open cash4765.586900000006
# ..........
# 2004-01-27 00:00:00
# Total portfolio value: 12433.001500000006  stock 1 number: 2275  stock 2 number: 76  open cash4764.149000000006
# ..........
# 2004-01-28 00:00:00
# Total portfolio value: 12175.336300000006  stock 1 number: 2276  stock 2 number: 76  open cash4762.673900000006
# ..........
# 2004-01-29 00:00:00
# Total portfolio value: 12013.953700000005  stock 1 number: 2277  stock 2 number: 76  open cash4761.211500000006
# ..........
# 2004-01-30 00:00:00
# Total portfolio value: 11822.875300000007  stock 1 number: 2278  stock 2 number: 76  open cash4759.762900000006
# ..........
# 2004-02-02 00:00:00
# Total portfolio value: 11877.841200000006  stock 1 number: 2279  stock 2 number: 76  open cash4758.307100000006
# ..........
# 2004-02-03 00:00:00
# Total portfolio value: 11675.605200000005  stock 1 number: 2280  stock 2 number: 76  open cash4756.8692000000065
# ..........
# 2004-02-04 00:00:00
# Total portfolio value: 11373.029500000006  stock 1 number: 2281  stock 2 number: 76  open cash4755.441000000006
# ..........
# 2004-02-05 00:00:00
# Total portfolio value: 11440.951100000006  stock 1 number: 2282  stock 2 number: 76  open cash4754.032500000007
# ..........
# 2004-02-06 00:00:00
# Total portfolio value: 11543.593000000008  stock 1 number: 2283  stock 2 number: 76  open cash4752.635200000007
# ..........
# 2004-02-09 00:00:00
# Total portfolio value: 11612.801000000007  stock 1 number: 2284  stock 2 number: 76  open cash4751.198600000007
# ..........
# 2004-02-10 00:00:00
# Total portfolio value: 11544.401000000007  stock 1 number: 2285  stock 2 number: 76  open cash4749.750000000007
# ..........
# 2004-02-11 00:00:00
# Total portfolio value: 11611.912200000008  stock 1 number: 2286  stock 2 number: 76  open cash4748.301400000008
# ..........
# 2004-02-12 00:00:00
# Total portfolio value: 11786.373000000007  stock 1 number: 2287  stock 2 number: 76  open cash4746.823600000008
# ..........
# 2004-02-13 00:00:00
# Total portfolio value: 11834.496200000009  stock 1 number: 2288  stock 2 number: 76  open cash4745.307400000008
# ..........
# 2004-02-17 00:00:00
# Total portfolio value: 11635.850800000007  stock 1 number: 2289  stock 2 number: 76  open cash4743.7798000000075
# ..........
# 2004-02-18 00:00:00
# Total portfolio value: 11588.936800000007  stock 1 number: 2290  stock 2 number: 76  open cash4742.300800000007
# ..........
# 2004-02-19 00:00:00
# Total portfolio value: 11590.159300000007  stock 1 number: 2291  stock 2 number: 76  open cash4740.816400000007
# ..........
# 2004-02-20 00:00:00
# Total portfolio value: 11445.979700000007  stock 1 number: 2292  stock 2 number: 76  open cash4739.324500000007
# ..........
# 2004-02-23 00:00:00
# Total portfolio value: 11466.447700000008  stock 1 number: 2293  stock 2 number: 76  open cash4737.883900000007
# ..........
# 2004-02-24 00:00:00
# Total portfolio value: 11325.051100000008  stock 1 number: 2294  stock 2 number: 76  open cash4736.447300000007
# ..........
# 2004-02-25 00:00:00
# Total portfolio value: 11230.585100000008  stock 1 number: 2295  stock 2 number: 76  open cash4735.029600000007
# ..........
# 2004-02-26 00:00:00
# Total portfolio value: 11359.277100000007  stock 1 number: 2296  stock 2 number: 76  open cash4733.606700000008
# ..........
# 2004-02-27 00:00:00
# Total portfolio value: 11410.333100000007  stock 1 number: 2297  stock 2 number: 76  open cash4732.144300000007
# ..........
# 2004-03-01 00:00:00
# Total portfolio value: 11533.069900000008  stock 1 number: 2298  stock 2 number: 76  open cash4730.673900000007
# ..........
# 2004-03-02 00:00:00
# Total portfolio value: 11504.197500000006  stock 1 number: 2299  stock 2 number: 76  open cash4729.131900000007
# ..........
# 2004-03-03 00:00:00
# Total portfolio value: 11374.077500000007  stock 1 number: 2300  stock 2 number: 76  open cash4727.597500000007
# ..........
# 2004-03-04 00:00:00
# Total portfolio value: 11536.900700000006  stock 1 number: 2301  stock 2 number: 76  open cash4726.086300000007
# ..........
# 2004-03-05 00:00:00
# Total portfolio value: 11723.796100000007  stock 1 number: 2302  stock 2 number: 76  open cash4724.551900000008
# ..........
# 2004-03-08 00:00:00
# Total portfolio value: 12015.60950000001  stock 1 number: 2303  stock 2 number: 76  open cash4722.954800000008
# ..........
# 2004-03-09 00:00:00
# Total portfolio value: 11831.012700000008  stock 1 number: 2304  stock 2 number: 76  open cash4721.239900000008
# ..........
# 2004-03-10 00:00:00
# Total portfolio value: 11947.958700000008  stock 1 number: 2305  stock 2 number: 76  open cash4719.581700000008
# ..........
# 2004-03-11 00:00:00
# Total portfolio value: 11865.586700000009  stock 1 number: 2306  stock 2 number: 76  open cash4717.854300000008
# ..........
# 2004-03-12 00:00:00
# Total portfolio value: 11893.882600000008  stock 1 number: 2307  stock 2 number: 76  open cash4716.108900000008
# ..........
# 2004-03-15 00:00:00
# Total portfolio value: 11922.421800000007  stock 1 number: 2308  stock 2 number: 76  open cash4714.359800000008
# ..........
# 2004-03-16 00:00:00
# Total portfolio value: 11790.273700000009  stock 1 number: 2309  stock 2 number: 76  open cash4712.6283000000085
# ..........
# 2004-03-17 00:00:00
# Total portfolio value: 11818.609700000008  stock 1 number: 2310  stock 2 number: 76  open cash4710.927700000008
# ..........
# 2004-03-18 00:00:00
# Total portfolio value: 11779.885400000008  stock 1 number: 2311  stock 2 number: 76  open cash4709.265500000009
# ..........
# 2004-03-19 00:00:00
# Total portfolio value: 11786.543000000009  stock 1 number: 2312  stock 2 number: 76  open cash4707.604600000009
# ..........
# 2004-03-22 00:00:00
# Total portfolio value: 11637.815200000008  stock 1 number: 2313  stock 2 number: 76  open cash4705.958900000009
# ..........
# 2004-03-23 00:00:00
# Total portfolio value: 11676.60820000001  stock 1 number: 2314  stock 2 number: 76  open cash4704.3338000000085
# ..........
# 2004-03-24 00:00:00
# Total portfolio value: 11519.342700000008  stock 1 number: 2315  stock 2 number: 76  open cash4702.674200000009
# ..........
# 2004-03-25 00:00:00
# Total portfolio value: 11611.785100000008  stock 1 number: 2316  stock 2 number: 76  open cash4701.054300000009
# ..........
# 2004-03-26 00:00:00
# Total portfolio value: 11885.724200000008  stock 1 number: 2317  stock 2 number: 76  open cash4699.383000000009
# ..........
# 2004-03-29 00:00:00
# Total portfolio value: 11961.67860000001  stock 1 number: 2318  stock 2 number: 76  open cash4697.659400000009
# ..........
# 2004-03-30 00:00:00
# Total portfolio value: 12078.96100000001  stock 1 number: 2319  stock 2 number: 76  open cash4695.905000000009
# ..........
# 2004-03-31 00:00:00
# Total portfolio value: 12165.60100000001  stock 1 number: 2320  stock 2 number: 76  open cash4694.121000000009
# ..........
# 2004-04-01 00:00:00
# Total portfolio value: 11991.235300000008  stock 1 number: 2321  stock 2 number: 76  open cash4692.3370000000095
# ..........
# 2004-04-02 00:00:00
# Total portfolio value: 12300.83890000001  stock 1 number: 2322  stock 2 number: 76  open cash4690.614700000009
# ..........
# 2004-04-05 00:00:00
# Total portfolio value: 12247.30940000001  stock 1 number: 2323  stock 2 number: 76  open cash4688.838600000009
# ..........
# 2004-04-06 00:00:00
# Total portfolio value: 12334.29540000001  stock 1 number: 2324  stock 2 number: 76  open cash4687.079000000009
# ..........
# 2004-04-07 00:00:00
# Total portfolio value: 12308.03290000001  stock 1 number: 2325  stock 2 number: 76  open cash4685.302900000009
# ..........
# 2004-04-08 00:00:00
# Total portfolio value: 12475.471300000008  stock 1 number: 2326  stock 2 number: 76  open cash4683.534500000009
# ..........
# 2004-04-12 00:00:00
# Total portfolio value: 12431.627400000008  stock 1 number: 2327  stock 2 number: 76  open cash4681.747700000009
# ..........
# 2004-04-13 00:00:00
# Total portfolio value: 12501.39220000001  stock 1 number: 2328  stock 2 number: 76  open cash4679.986600000009
# ..........
# 2004-04-14 00:00:00
# Total portfolio value: 12160.853500000008  stock 1 number: 2329  stock 2 number: 76  open cash4678.193900000009
# ..........
# 2004-04-15 00:00:00
# Total portfolio value: 12570.731500000009  stock 1 number: 2330  stock 2 number: 76  open cash4676.481500000009
# ..........
# 2004-04-16 00:00:00
# Total portfolio value: 12592.49960000001  stock 1 number: 2331  stock 2 number: 76  open cash4674.624500000009
# ..........
# 2004-04-19 00:00:00
# Total portfolio value: 12318.888400000009  stock 1 number: 2332  stock 2 number: 76  open cash4672.762400000009
# ..........
# 2004-04-20 00:00:00
# Total portfolio value: 12506.279500000008  stock 1 number: 2333  stock 2 number: 76  open cash4670.961900000008
# ..........
# 2004-04-21 00:00:00
# Total portfolio value: 12233.03290000001  stock 1 number: 2334  stock 2 number: 76  open cash4669.154700000008
# ..........
# 2004-04-22 00:00:00
# Total portfolio value: 12280.628900000007  stock 1 number: 2335  stock 2 number: 76  open cash4667.387400000008
# ..........
# 2004-04-23 00:00:00
# Total portfolio value: 12309.299300000006  stock 1 number: 2336  stock 2 number: 76  open cash4665.622500000008
# ..........
# 2004-04-26 00:00:00
# Total portfolio value: 12306.219400000007  stock 1 number: 2337  stock 2 number: 76  open cash4663.843700000008
# ..........
# 2004-04-27 00:00:00
# Total portfolio value: 12359.663400000009  stock 1 number: 2338  stock 2 number: 76  open cash4662.077600000008
# ..........
# 2004-04-28 00:00:00
# Total portfolio value: 12296.218200000008  stock 1 number: 2339  stock 2 number: 76  open cash4660.333500000008
# ..........
# 2004-04-29 00:00:00
# Total portfolio value: 12186.916200000007  stock 1 number: 2340  stock 2 number: 76  open cash4658.616200000008
# ..........
# 2004-04-30 00:00:00
# Total portfolio value: 12189.387500000008  stock 1 number: 2341  stock 2 number: 76  open cash4656.9232000000075
# ..........
# 2004-05-03 00:00:00
# Total portfolio value: 11856.362500000007  stock 1 number: 2342  stock 2 number: 76  open cash4655.200900000007
# ..........
# 2004-05-04 00:00:00
# Total portfolio value: 11938.460200000009  stock 1 number: 2343  stock 2 number: 76  open cash4653.5361000000075
# ..........
# 2004-05-05 00:00:00
# Total portfolio value: 11925.413000000008  stock 1 number: 2344  stock 2 number: 76  open cash4651.867400000007
# ..........
# 2004-05-06 00:00:00
# Total portfolio value: 11927.78650000001  stock 1 number: 2345  stock 2 number: 76  open cash4650.190000000008
# ..........
# 2004-05-07 00:00:00
# Total portfolio value: 11906.350300000007  stock 1 number: 2346  stock 2 number: 76  open cash4648.4983000000075
# ..........
# 2004-05-10 00:00:00
# Total portfolio value: 11728.276800000007  stock 1 number: 2347  stock 2 number: 76  open cash4646.796300000007
# ..........
# 2004-05-11 00:00:00
# Total portfolio value: 11799.334000000006  stock 1 number: 2348  stock 2 number: 76  open cash4645.114800000008
# ..........
# 2004-05-12 00:00:00
# Total portfolio value: 11862.204500000007  stock 1 number: 2349  stock 2 number: 76  open cash4643.424400000007
# ..........
# 2004-05-13 00:00:00
# Total portfolio value: 11951.199500000006  stock 1 number: 2350  stock 2 number: 76  open cash4641.709500000007
# ..........
# 2004-05-14 00:00:00
# Total portfolio value: 12037.533400000008  stock 1 number: 2351  stock 2 number: 76  open cash4639.972900000007
# ..........
# 2004-05-17 00:00:00
# Total portfolio value: 11869.691800000008  stock 1 number: 2352  stock 2 number: 76  open cash4638.237400000007
# ..........
# 2004-05-18 00:00:00
# Total portfolio value: 11908.281000000006  stock 1 number: 2353  stock 2 number: 76  open cash4636.527700000007
# ..........
# 2004-05-19 00:00:00
# Total portfolio value: 11985.539200000007  stock 1 number: 2354  stock 2 number: 76  open cash4634.801600000007
# ..........
# 2004-05-20 00:00:00
# Total portfolio value: 11812.309200000007  stock 1 number: 2355  stock 2 number: 76  open cash4633.047200000007
# ..........
# 2004-05-21 00:00:00
# Total portfolio value: 11818.761600000007  stock 1 number: 2356  stock 2 number: 76  open cash4631.342800000008
# ..........
# 2004-05-24 00:00:00
# Total portfolio value: 11874.704200000007  stock 1 number: 2357  stock 2 number: 76  open cash4629.620500000007
# ..........
# 2004-05-25 00:00:00
# Total portfolio value: 11953.550200000009  stock 1 number: 2358  stock 2 number: 76  open cash4627.876400000007
# ..........
# 2004-05-26 00:00:00
# Total portfolio value: 12221.063300000007  stock 1 number: 2359  stock 2 number: 76  open cash4626.115300000008
# ..........
# 2004-05-27 00:00:00
# Total portfolio value: 12367.523300000008  stock 1 number: 2360  stock 2 number: 76  open cash4624.303300000008
# ..........
# 2004-05-28 00:00:00
# Total portfolio value: 12459.841700000008  stock 1 number: 2361  stock 2 number: 76  open cash4622.479800000007
# ..........
# 2004-06-01 00:00:00
# Total portfolio value: 12461.087500000009  stock 1 number: 2362  stock 2 number: 76  open cash4620.681900000008
# ..........
# 2004-06-02 00:00:00
# Total portfolio value: 12694.924400000007  stock 1 number: 2363  stock 2 number: 76  open cash4618.903100000008
# ..........
# 2004-06-03 00:00:00
# Total portfolio value: 12759.184000000007  stock 1 number: 2364  stock 2 number: 76  open cash4617.108000000007
# ..........
# 2004-06-04 00:00:00
# Total portfolio value: 12756.341000000008  stock 1 number: 2365  stock 2 number: 76  open cash4615.2690000000075
# ..........
# 2004-06-07 00:00:00
# Total portfolio value: 12941.457200000008  stock 1 number: 2366  stock 2 number: 76  open cash4613.440200000007
# ..........
# 2004-06-08 00:00:00
# Total portfolio value: 13052.442600000008  stock 1 number: 2367  stock 2 number: 76  open cash4611.580700000008
# ..........
# 2004-06-09 00:00:00
# Total portfolio value: 13092.506600000008  stock 1 number: 2368  stock 2 number: 76  open cash4609.665000000008
# ..........
# 2004-06-10 00:00:00
# Total portfolio value: 13015.797200000008  stock 1 number: 2369  stock 2 number: 76  open cash4607.738800000008
# ..........
# 2004-06-14 00:00:00
# Total portfolio value: 13013.471200000009  stock 1 number: 2370  stock 2 number: 76  open cash4605.805200000008
# ..........
# 2004-06-15 00:00:00
# Total portfolio value: 12978.133000000009  stock 1 number: 2371  stock 2 number: 76  open cash4603.843400000008
# ..........
# 2004-06-16 00:00:00
# Total portfolio value: 13060.809000000008  stock 1 number: 2372  stock 2 number: 76  open cash4601.905800000008
# ..........
# 2004-06-17 00:00:00
# Total portfolio value: 13411.942400000007  stock 1 number: 2373  stock 2 number: 76  open cash4599.945200000007
# ..........
# 2004-06-18 00:00:00
# Total portfolio value: 13327.450200000007  stock 1 number: 2374  stock 2 number: 76  open cash4597.848800000007
# ..........
# 2004-06-21 00:00:00
# Total portfolio value: 13401.502700000006  stock 1 number: 2375  stock 2 number: 76  open cash4595.762700000007
# ..........
# 2004-06-22 00:00:00
# Total portfolio value: 13282.653900000008  stock 1 number: 2376  stock 2 number: 76  open cash4593.641900000007
# ..........
# 2004-06-23 00:00:00
# Total portfolio value: 13321.453400000006  stock 1 number: 2377  stock 2 number: 76  open cash4591.572400000007
# ..........
# 2004-06-24 00:00:00
# Total portfolio value: 13593.378600000007  stock 1 number: 2378  stock 2 number: 76  open cash4589.459400000007
# ..........
# 2004-06-25 00:00:00
# Total portfolio value: 13491.650000000009  stock 1 number: 2379  stock 2 number: 76  open cash4587.303000000007
# ..........
# 2004-06-28 00:00:00
# Total portfolio value: 13718.894000000008  stock 1 number: 2380  stock 2 number: 76  open cash4585.190000000007
# ..........
# 2004-06-29 00:00:00
# Total portfolio value: 13524.164700000005  stock 1 number: 2381  stock 2 number: 76  open cash4583.019200000007
# ..........
# 2004-06-30 00:00:00
# Total portfolio value: 13619.105700000007  stock 1 number: 2382  stock 2 number: 76  open cash4580.963700000007
# ..........
# 2004-07-01 00:00:00
# Total portfolio value: 13561.321300000007  stock 1 number: 2383  stock 2 number: 76  open cash4578.8827000000065
# ..........
# 2004-07-02 00:00:00
# Total portfolio value: 13221.321300000007  stock 1 number: 2384  stock 2 number: 76  open cash4576.828500000007
# ..........
# 2004-07-06 00:00:00
# Total portfolio value: 13306.768300000007  stock 1 number: 2385  stock 2 number: 76  open cash4574.879300000007
# ..........
# 2004-07-07 00:00:00
# Total portfolio value: 13138.597100000008  stock 1 number: 2386  stock 2 number: 76  open cash4572.887900000007
# ..........
# 2004-07-08 00:00:00
# Total portfolio value: 12863.523900000007  stock 1 number: 2387  stock 2 number: 76  open cash4570.915700000007
# ..........
# 2004-07-09 00:00:00
# Total portfolio value: 12982.295900000008  stock 1 number: 2388  stock 2 number: 76  open cash4568.987100000007
# ..........
# 2004-07-12 00:00:00
# Total portfolio value: 12819.063100000007  stock 1 number: 2389  stock 2 number: 76  open cash4567.049500000006
# ..........
# 2004-07-13 00:00:00
# Total portfolio value: 12775.085100000008  stock 1 number: 2390  stock 2 number: 76  open cash4565.127100000006
# ..........
# 2004-07-14 00:00:00
# Total portfolio value: 12725.207100000007  stock 1 number: 2391  stock 2 number: 76  open cash4563.254900000006
# ..........
# 2004-07-15 00:00:00
# Total portfolio value: 13312.691900000005  stock 1 number: 2392  stock 2 number: 76  open cash4561.4007000000065
# ..........
# 2004-07-16 00:00:00
# Total portfolio value: 13326.522500000006  stock 1 number: 2393  stock 2 number: 76  open cash4559.317100000007
# ..........
# 2004-07-19 00:00:00
# Total portfolio value: 13060.260300000005  stock 1 number: 2394  stock 2 number: 76  open cash4557.209300000007
# ..........
# 2004-07-20 00:00:00
# Total portfolio value: 12956.459300000006  stock 1 number: 2395  stock 2 number: 76  open cash4555.157800000007
# ..........
# 2004-07-21 00:00:00
# Total portfolio value: 13104.841300000007  stock 1 number: 2396  stock 2 number: 76  open cash4553.114100000007
# ..........
# 2004-07-22 00:00:00
# Total portfolio value: 12682.545500000007  stock 1 number: 2397  stock 2 number: 76  open cash4551.045900000007
# ..........
# 2004-07-23 00:00:00
# Total portfolio value: 12643.979700000007  stock 1 number: 2398  stock 2 number: 76  open cash4549.039100000007
# ..........
# 2004-07-26 00:00:00
# Total portfolio value: 12327.673300000006  stock 1 number: 2399  stock 2 number: 76  open cash4547.009400000007
# ..........
# 2004-07-27 00:00:00
# Total portfolio value: 12403.593300000008  stock 1 number: 2400  stock 2 number: 76  open cash4545.033300000007
# ..........
# 2004-07-28 00:00:00
# Total portfolio value: 12491.829100000008  stock 1 number: 2401  stock 2 number: 76  open cash4542.999600000007
# ..........
# 2004-07-29 00:00:00
# Total portfolio value: 12449.532100000008  stock 1 number: 2402  stock 2 number: 76  open cash4540.930100000008
# ..........
# 2004-07-30 00:00:00
# Total portfolio value: 12493.126600000007  stock 1 number: 2403  stock 2 number: 76  open cash4538.849100000008
# ..........
# 2004-08-02 00:00:00
# Total portfolio value: 12266.917800000008  stock 1 number: 2404  stock 2 number: 76  open cash4536.756600000008
# ..........
# 2004-08-03 00:00:00
# Total portfolio value: 12295.161800000009  stock 1 number: 2405  stock 2 number: 76  open cash4534.756300000008
# ..........
# 2004-08-04 00:00:00
# Total portfolio value: 12140.565400000007  stock 1 number: 2406  stock 2 number: 76  open cash4532.739200000008
# ..........
# 2004-08-05 00:00:00
# Total portfolio value: 12274.337400000008  stock 1 number: 2407  stock 2 number: 76  open cash4530.741500000008
# ..........
# 2004-08-06 00:00:00
# Total portfolio value: 11972.41740000001  stock 1 number: 2408  stock 2 number: 76  open cash4528.707800000008
# ..........
# 2004-08-09 00:00:00
# Total portfolio value: 11818.095300000008  stock 1 number: 2409  stock 2 number: 76  open cash4526.729100000009
# ..........
# 2004-08-10 00:00:00
# Total portfolio value: 11927.562300000009  stock 1 number: 2410  stock 2 number: 76  open cash4524.817300000009
# ..........
# 2004-08-11 00:00:00
# Total portfolio value: 12090.53620000001  stock 1 number: 2411  stock 2 number: 76  open cash4522.870800000009
# ..........
# 2004-08-12 00:00:00
# Total portfolio value: 11992.641000000009  stock 1 number: 2412  stock 2 number: 76  open cash4520.879400000009
# ..........
# 2004-08-13 00:00:00
# Total portfolio value: 12034.44290000001  stock 1 number: 2413  stock 2 number: 76  open cash4518.922600000009
# ..........
# 2004-08-16 00:00:00
# Total portfolio value: 12036.801700000007  stock 1 number: 2414  stock 2 number: 76  open cash4516.959500000009
# ..........
# 2004-08-17 00:00:00
# Total portfolio value: 12172.41470000001  stock 1 number: 2415  stock 2 number: 76  open cash4514.9822000000095
# ..........
# 2004-08-18 00:00:00
# Total portfolio value: 12116.28990000001  stock 1 number: 2416  stock 2 number: 76  open cash4513.0227000000095
# ..........
# 2004-08-19 00:00:00
# Total portfolio value: 12454.89790000001  stock 1 number: 2417  stock 2 number: 76  open cash4511.068500000009
# ..........
# 2004-08-20 00:00:00
# Total portfolio value: 12193.74310000001  stock 1 number: 2418  stock 2 number: 76  open cash4509.050300000009
# ..........
# 2004-08-23 00:00:00
# Total portfolio value: 12309.472500000007  stock 1 number: 2419  stock 2 number: 76  open cash4507.080700000009
# ..........
# 2004-08-24 00:00:00
# Total portfolio value: 12369.980500000009  stock 1 number: 2420  stock 2 number: 76  open cash4505.1085000000085
# ..........
# 2004-08-25 00:00:00
# Total portfolio value: 12415.664600000007  stock 1 number: 2421  stock 2 number: 76  open cash4503.106900000009
# ..........
# 2004-08-26 00:00:00
# Total portfolio value: 12697.61800000001  stock 1 number: 2422  stock 2 number: 76  open cash4501.063200000009
# ..........
# 2004-08-27 00:00:00
# Total portfolio value: 12930.414000000008  stock 1 number: 2423  stock 2 number: 76  open cash4498.939800000008
# ..........
# 2004-08-30 00:00:00
# Total portfolio value: 12805.281200000009  stock 1 number: 2424  stock 2 number: 76  open cash4496.724400000008
# ..........
# 2004-08-31 00:00:00
# Total portfolio value: 12711.378700000008  stock 1 number: 2425  stock 2 number: 76  open cash4494.546200000008
# ..........
# 2004-09-01 00:00:00
# Total portfolio value: 12725.582700000008  stock 1 number: 2426  stock 2 number: 76  open cash4492.364100000008
# ..........
# 2004-09-02 00:00:00
# Total portfolio value: 12897.261700000006  stock 1 number: 2427  stock 2 number: 76  open cash4490.168000000008
# ..........
# 2004-09-03 00:00:00
# Total portfolio value: 12900.115700000006  stock 1 number: 2428  stock 2 number: 76  open cash4487.8949000000075
# ..........
# 2004-09-07 00:00:00
# Total portfolio value: 12958.231400000008  stock 1 number: 2429  stock 2 number: 76  open cash4485.651300000008
# ..........
# 2004-09-08 00:00:00
# Total portfolio value: 12958.28440000001  stock 1 number: 2430  stock 2 number: 76  open cash4483.384400000008
# ..........
# 2004-09-09 00:00:00
# Total portfolio value: 13005.834900000007  stock 1 number: 2431  stock 2 number: 76  open cash4481.098400000008
# ..........
# 2004-09-10 00:00:00
# Total portfolio value: 12938.134100000008  stock 1 number: 2432  stock 2 number: 76  open cash4478.786900000008
# ..........
# 2004-09-13 00:00:00
# Total portfolio value: 13036.793600000008  stock 1 number: 2433  stock 2 number: 76  open cash4476.502300000008
# ..........
# 2004-09-14 00:00:00
# Total portfolio value: 13031.736400000009  stock 1 number: 2434  stock 2 number: 76  open cash4474.206200000009
# ..........
# 2004-09-15 00:00:00
# Total portfolio value: 13198.944400000008  stock 1 number: 2435  stock 2 number: 76  open cash4471.945900000009
# ..........
# 2004-09-16 00:00:00
# ...
# ..........
# 2004-12-01 00:00:00
# Total portfolio value: 18031.767000000007  stock 1 number: 2489  stock 2 number: 76  open cash4307.485600000007
# ..........
# 2004-12-02 00:00:00
# Total portfolio value: 17858.244000000006  stock 1 number: 2490  stock 2 number: 76  open cash4303.1930000000075
# ..........
# 2004-12-03 00:00:00
# Total portfolio value: 17663.614900000008  stock 1 number: 2491  stock 2 number: 76  open cash4298.959100000007
# ..........
# 2004-12-06 00:00:00
# Total portfolio value: 17564.898100000006  stock 1 number: 2492  stock 2 number: 76  open cash4294.825300000008
# ..........
# 2004-12-07 00:00:00
# Total portfolio value: 17814.85650000001  stock 1 number: 2493  stock 2 number: 76  open cash4290.7119000000075
# ..........
# 2004-12-08 00:00:00
# Total portfolio value: 17272.32510000001  stock 1 number: 2494  stock 2 number: 76  open cash4286.489700000007
# ..........
# 2004-12-09 00:00:00
# Total portfolio value: 17227.257600000008  stock 1 number: 2495  stock 2 number: 76  open cash4282.450600000007
# ..........
# 2004-12-10 00:00:00
# Total portfolio value: 17689.713600000006  stock 1 number: 2496  stock 2 number: 76  open cash4278.432000000007
# ..........
# 2004-12-13 00:00:00
# Total portfolio value: 17772.699200000006  stock 1 number: 2497  stock 2 number: 76  open cash4274.267400000007
# ..........
# 2004-12-14 00:00:00
# Total portfolio value: 17769.842600000007  stock 1 number: 2498  stock 2 number: 76  open cash4270.058000000007
# ..........
# 2004-12-15 00:00:00
# Total portfolio value: 17786.021600000007  stock 1 number: 2499  stock 2 number: 76  open cash4265.875300000007
# ..........
# 2004-12-16 00:00:00
# Total portfolio value: 17972.32160000001  stock 1 number: 2500  stock 2 number: 76  open cash4261.691600000007
# ..........
# 2004-12-17 00:00:00
# Total portfolio value: 18025.67390000001  stock 1 number: 2501  stock 2 number: 76  open cash4257.450100000007
# ..........
# 2004-12-20 00:00:00
# Total portfolio value: 17791.41730000001  stock 1 number: 2502  stock 2 number: 76  open cash4253.166300000007
# ..........
# 2004-12-21 00:00:00
# Total portfolio value: 17391.565500000004  stock 1 number: 2503  stock 2 number: 76  open cash4248.965800000007
# ..........
# 2004-12-22 00:00:00
# Total portfolio value: 17465.643900000006  stock 1 number: 2504  stock 2 number: 76  open cash4244.895900000007
# ..........
# 2004-12-23 00:00:00
# Total portfolio value: 17465.648900000007  stock 1 number: 2505  stock 2 number: 76  open cash4240.786400000007
# ..........
# 2004-12-27 00:00:00
# Total portfolio value: 17631.595300000004  stock 1 number: 2506  stock 2 number: 76  open cash4236.703900000007
# ..........
# 2004-12-28 00:00:00
# Total portfolio value: 17735.108500000006  stock 1 number: 2507  stock 2 number: 76  open cash4232.557000000007
# ..........
# 2004-12-29 00:00:00
# Total portfolio value: 17897.816900000005  stock 1 number: 2508  stock 2 number: 76  open cash4228.502500000007
# ..........
# 2004-12-30 00:00:00
# Total portfolio value: 18059.622800000005  stock 1 number: 2509  stock 2 number: 76  open cash4224.410700000007
# ..........
# 2004-12-31 00:00:00
# Total portfolio value: 18086.019800000005  stock 1 number: 2510  stock 2 number: 76  open cash4220.263800000007
# ..........
# 2005-01-03 00:00:00
# Total portfolio value: 18064.040100000006  stock 1 number: 2511  stock 2 number: 76  open cash4216.108200000007
# ..........
# 2005-01-04 00:00:00
# Total portfolio value: 17706.31530000001  stock 1 number: 2512  stock 2 number: 76  open cash4211.955300000007
# ..........
# 2005-01-05 00:00:00
# Total portfolio value: 17655.414800000006  stock 1 number: 2513  stock 2 number: 76  open cash4207.8728000000065
# ..........
# 2005-01-06 00:00:00
# Total portfolio value: 17815.216200000006  stock 1 number: 2514  stock 2 number: 76  open cash4203.778800000006
# ..........
# 2005-01-07 00:00:00
# Total portfolio value: 17812.398700000005  stock 1 number: 2515  stock 2 number: 76  open cash4199.629700000007
# ..........
# 2005-01-10 00:00:00
# Total portfolio value: 18637.68630000001  stock 1 number: 2516  stock 2 number: 76  open cash4195.465100000007
# ..........
# 2005-01-11 00:00:00
# Total portfolio value: 18335.42090000001  stock 1 number: 2517  stock 2 number: 76  open cash4190.989400000007
# ..........
# 2005-01-12 00:00:00
# Total portfolio value: 17902.416900000004  stock 1 number: 2518  stock 2 number: 76  open cash4186.619900000007
# ..........
# 2005-01-13 00:00:00
# Total portfolio value: 19321.461700000007  stock 1 number: 2519  stock 2 number: 76  open cash4182.428400000007
# ..........
# 2005-01-14 00:00:00
# Total portfolio value: 18762.887700000007  stock 1 number: 2518  stock 2 number: 76  open cash4187.159100000007
# ..........
# 2005-01-18 00:00:00
# Total portfolio value: 18822.173800000004  stock 1 number: 2519  stock 2 number: 76  open cash4182.661400000007
# ..........
# 2005-01-19 00:00:00
# Total portfolio value: 18942.213800000005  stock 1 number: 2520  stock 2 number: 76  open cash4178.181800000008
# ..........
# 2005-01-20 00:00:00
# Total portfolio value: 18587.781700000007  stock 1 number: 2521  stock 2 number: 76  open cash4173.661200000008
# ..........
# 2005-01-21 00:00:00
# Total portfolio value: 18855.914500000006  stock 1 number: 2522  stock 2 number: 76  open cash4169.200700000008
# ..........
# 2005-01-24 00:00:00
# Total portfolio value: 18793.179800000005  stock 1 number: 2523  stock 2 number: 76  open cash4164.637800000008
# ..........
# 2005-01-25 00:00:00
# Total portfolio value: 18785.66700000001  stock 1 number: 2524  stock 2 number: 76  open cash4160.083800000008
# ..........
# 2005-01-26 00:00:00
# Total portfolio value: 19041.10450000001  stock 1 number: 2525  stock 2 number: 76  open cash4155.512000000008
# ..........
# 2005-01-27 00:00:00
# Total portfolio value: 18956.481300000007  stock 1 number: 2526  stock 2 number: 76  open cash4150.858300000008
# ..........
# 2005-01-28 00:00:00
# Total portfolio value: 19085.50270000001  stock 1 number: 2527  stock 2 number: 76  open cash4146.237800000008
# ..........
# 2005-01-31 00:00:00
# Total portfolio value: 19480.96510000001  stock 1 number: 2528  stock 2 number: 76  open cash4141.589100000008
# ..........
# 2005-02-01 00:00:00
# Total portfolio value: 19880.322300000007  stock 1 number: 2527  stock 2 number: 76  open cash4146.378600000008
# ..........
# 2005-02-02 00:00:00
# Total portfolio value: 20042.51350000001  stock 1 number: 2526  stock 2 number: 76  open cash4151.311700000008
# ..........
# 2005-02-03 00:00:00
# Total portfolio value: 19619.798500000008  stock 1 number: 2525  stock 2 number: 76  open cash4156.306000000009
# ..........
# 2005-02-04 00:00:00
# Total portfolio value: 19475.632900000008  stock 1 number: 2524  stock 2 number: 76  open cash4161.379700000009
# ..........
# 2005-02-07 00:00:00
# Total portfolio value: 19645.96950000001  stock 1 number: 2523  stock 2 number: 76  open cash4166.374000000009
# ..........
# 2005-02-08 00:00:00
# Total portfolio value: 19660.78470000001  stock 1 number: 2522  stock 2 number: 76  open cash4171.432500000009
# ..........
# 2005-02-09 00:00:00
# Total portfolio value: 20058.950000000008  stock 1 number: 2521  stock 2 number: 76  open cash4176.502600000009
# ..........
# 2005-02-10 00:00:00
# Total portfolio value: 19634.67400000001  stock 1 number: 2520  stock 2 number: 76  open cash4181.702000000009
# ..........
# 2005-02-11 00:00:00
# Total portfolio value: 19791.401300000005  stock 1 number: 2519  stock 2 number: 76  open cash4186.745100000009
# ..........
# 2005-02-14 00:00:00
# Total portfolio value: 20238.58890000001  stock 1 number: 2518  stock 2 number: 76  open cash4191.86490000001
# ..........
# 2005-02-15 00:00:00
# Total portfolio value: 20932.82470000001  stock 1 number: 2517  stock 2 number: 76  open cash4197.162900000009
# ..........
# 2005-02-16 00:00:00
# Total portfolio value: 21138.519100000005  stock 1 number: 2516  stock 2 number: 76  open cash4202.71830000001
# ..........
# 2005-02-17 00:00:00
# Total portfolio value: 21525.94860000001  stock 1 number: 2515  stock 2 number: 76  open cash4208.362100000009
# ..........
# 2005-02-18 00:00:00
# Total portfolio value: 21047.395200000014  stock 1 number: 2514  stock 2 number: 76  open cash4214.167200000009
# ..........
# 2005-02-22 00:00:00
# Total portfolio value: 20788.741600000012  stock 1 number: 2513  stock 2 number: 76  open cash4219.789200000009
# ..........
# 2005-02-23 00:00:00
# Total portfolio value: 20834.69200000001  stock 1 number: 2512  stock 2 number: 76  open cash4225.32400000001
# ..........
# 2005-02-24 00:00:00
# Total portfolio value: 20987.33690000001  stock 1 number: 2511  stock 2 number: 76  open cash4230.87800000001
# ..........
# 2005-02-25 00:00:00
# Total portfolio value: 21282.36890000001  stock 1 number: 2510  stock 2 number: 76  open cash4236.52790000001
# ..........
# 2005-02-28 00:00:00
# Total portfolio value: 21231.981800000012  stock 1 number: 2509  stock 2 number: 76  open cash4242.26900000001
# ..........
# 2005-03-01 00:00:00
# Total portfolio value: 21392.44060000001  stock 1 number: 2508  stock 2 number: 76  open cash4247.98820000001
# ..........
# 2005-03-02 00:00:00
# Total portfolio value: 21136.430600000007  stock 1 number: 2507  stock 2 number: 76  open cash4253.76350000001
# ..........
# 2005-03-03 00:00:00
# Total portfolio value: 21207.55540000001  stock 1 number: 2506  stock 2 number: 76  open cash4259.42880000001
# ..........
# 2005-03-04 00:00:00
# Total portfolio value: 20392.93390000001  stock 1 number: 2505  stock 2 number: 76  open cash4265.11490000001
# ..........
# 2005-03-07 00:00:00
# Total portfolio value: 20719.705900000008  stock 1 number: 2504  stock 2 number: 76  open cash4270.46670000001
# ..........
# 2005-03-08 00:00:00
# Total portfolio value: 20460.108300000007  stock 1 number: 2503  stock 2 number: 76  open cash4275.94900000001
# ..........
# 2005-03-09 00:00:00
# Total portfolio value: 19689.022300000008  stock 1 number: 2502  stock 2 number: 76  open cash4281.312100000009
# ..........
# 2005-03-10 00:00:00
# Total portfolio value: 19645.70230000001  stock 1 number: 2501  stock 2 number: 76  open cash4286.382200000009
# ..........
# 2005-03-11 00:00:00
# Total portfolio value: 19788.51230000001  stock 1 number: 2500  stock 2 number: 76  open cash4291.452300000009
# ..........
# 2005-03-14 00:00:00
# Total portfolio value: 19898.06390000001  stock 1 number: 2499  stock 2 number: 76  open cash4296.592900000009
# ..........
# 2005-03-15 00:00:00
# Total portfolio value: 19931.92010000001  stock 1 number: 2498  stock 2 number: 76  open cash4301.781900000009
# ..........
# 2005-03-16 00:00:00
# Total portfolio value: 20082.33560000001  stock 1 number: 2497  stock 2 number: 76  open cash4306.987800000009
# ..........
# 2005-03-17 00:00:00
# Total portfolio value: 20149.111600000007  stock 1 number: 2496  stock 2 number: 76  open cash4312.265200000009
# ..........
# 2005-03-18 00:00:00
# Total portfolio value: 20737.973100000007  stock 1 number: 2495  stock 2 number: 76  open cash4317.586100000009
# ..........
# 2005-03-21 00:00:00
# Total portfolio value: 20758.04310000001  stock 1 number: 2494  stock 2 number: 76  open cash4323.128700000008
# ..........
# 2005-03-22 00:00:00
# Total portfolio value: 20852.19630000001  stock 1 number: 2493  stock 2 number: 76  open cash4328.676300000008
# ..........
# 2005-03-23 00:00:00
# Total portfolio value: 20406.24470000001  stock 1 number: 2492  stock 2 number: 76  open cash4334.276300000009
# ..........
# 2005-03-24 00:00:00
# Total portfolio value: 20586.303000000007  stock 1 number: 2491  stock 2 number: 76  open cash4339.719000000008
# ..........
# 2005-03-28 00:00:00
# Total portfolio value: 20486.497000000007  stock 1 number: 2490  stock 2 number: 76  open cash4345.223000000008
# ..........
# 2005-03-29 00:00:00
# Total portfolio value: 20442.645000000008  stock 1 number: 2489  stock 2 number: 76  open cash4350.697600000008
# ..........
# 2005-03-30 00:00:00
# Total portfolio value: 20281.875400000008  stock 1 number: 2488  stock 2 number: 76  open cash4356.144200000008
# ..........
# 2005-03-31 00:00:00
# Total portfolio value: 20500.062300000005  stock 1 number: 2487  stock 2 number: 76  open cash4361.521600000008
# ..........
# 2005-04-01 00:00:00
# Total portfolio value: 20387.98630000001  stock 1 number: 2486  stock 2 number: 76  open cash4366.957700000008
# ..........
# 2005-04-04 00:00:00
# Total portfolio value: 19935.225300000006  stock 1 number: 2485  stock 2 number: 76  open cash4372.347800000008
# ..........
# 2005-04-05 00:00:00
# Total portfolio value: 20145.494500000008  stock 1 number: 2484  stock 2 number: 76  open cash4377.571300000008
# ..........
# 2005-04-06 00:00:00
# Total portfolio value: 20534.904400000007  stock 1 number: 2483  stock 2 number: 76  open cash4382.846100000008
# ..........
# 2005-04-07 00:00:00
# Total portfolio value: 20474.070000000007  stock 1 number: 2482  stock 2 number: 76  open cash4388.2762000000075
# ..........
# 2005-04-08 00:00:00
# Total portfolio value: 20893.811200000007  stock 1 number: 2481  stock 2 number: 76  open cash4393.697100000008
# ..........
# 2005-04-11 00:00:00
# Total portfolio value: 21075.02720000001  stock 1 number: 2480  stock 2 number: 76  open cash4399.283200000008
# ..........
# 2005-04-12 00:00:00
# Total portfolio value: 20515.27240000001  stock 1 number: 2479  stock 2 number: 76  open cash4404.948500000008
# ..........
# 2005-04-13 00:00:00
# Total portfolio value: 20659.904600000005  stock 1 number: 2478  stock 2 number: 76  open cash4410.392600000007
# ..........
# 2005-04-14 00:00:00
# Total portfolio value: 19326.366500000007  stock 1 number: 2477  stock 2 number: 76  open cash4415.896600000007
# ..........
# 2005-04-15 00:00:00
# Total portfolio value: 18596.063100000007  stock 1 number: 2478  stock 2 number: 76  open cash4410.927900000007
# ..........
# 2005-04-18 00:00:00
# Total portfolio value: 18042.356400000008  stock 1 number: 2479  stock 2 number: 76  open cash4406.239500000007
# ..........
# 2005-04-19 00:00:00
# Total portfolio value: 18531.23640000001  stock 1 number: 2480  stock 2 number: 76  open cash4401.748400000007
# ..........
# 2005-04-20 00:00:00
# Total portfolio value: 18882.34500000001  stock 1 number: 2481  stock 2 number: 76  open cash4397.066300000007
# ..........
# 2005-04-21 00:00:00
# Total portfolio value: 18502.129800000006  stock 1 number: 2482  stock 2 number: 76  open cash4392.243600000007
# ..........
# 2005-04-22 00:00:00
# Total portfolio value: 18644.60200000001  stock 1 number: 2483  stock 2 number: 76  open cash4387.584500000007
# ..........
# 2005-04-25 00:00:00
# Total portfolio value: 18509.258800000007  stock 1 number: 2484  stock 2 number: 76  open cash4382.872000000008
# ..........
# 2005-04-26 00:00:00
# Total portfolio value: 18602.88330000001  stock 1 number: 2485  stock 2 number: 76  open cash4378.1993000000075
# ..........
# 2005-04-27 00:00:00
# Total portfolio value: 18109.079900000008  stock 1 number: 2486  stock 2 number: 76  open cash4373.4929000000075
# ..........
# 2005-04-28 00:00:00
# Total portfolio value: 18334.976500000008  stock 1 number: 2487  stock 2 number: 76  open cash4368.9084000000075
# ..........
# 2005-04-29 00:00:00
# Total portfolio value: 18336.571700000008  stock 1 number: 2488  stock 2 number: 76  open cash4364.262100000007
# ..........
# 2005-05-02 00:00:00
# Total portfolio value: 18371.161200000006  stock 1 number: 2489  stock 2 number: 76  open cash4359.645400000008
# ..........
# 2005-05-03 00:00:00
# Total portfolio value: 18466.33820000001  stock 1 number: 2490  stock 2 number: 76  open cash4355.003200000007
# ..........
# 2005-05-04 00:00:00
# Total portfolio value: 18443.341900000007  stock 1 number: 2491  stock 2 number: 76  open cash4350.341700000007
# ..........
# 2005-05-05 00:00:00
# Total portfolio value: 18800.079900000008  stock 1 number: 2492  stock 2 number: 76  open cash4345.699500000007
# ..........
# 2005-05-06 00:00:00
# Total portfolio value: 18746.48520000001  stock 1 number: 2493  stock 2 number: 76  open cash4340.935800000007
# ..........
# 2005-05-09 00:00:00
# Total portfolio value: 18848.939800000007  stock 1 number: 2494  stock 2 number: 76  open cash4336.200000000006
# --------------------------------
# Total Profit: $8848.94
# Total No. of days played: 499  out of overall days:  500
# Total portfolio value: 18848.939800000007  stock 1 number: 2495  stock 2 number: 76  open cash4331.428300000006
# --------------------------------

# %% [markdown]
# ## Plot Portfolio Value after 1) Training and Testing vs 2) Benchmarking over Test Data

# %%
# Test Stock Prices and actions taken by agent Stock Plot
import matplotlib.pyplot as plt
import datetime
import numpy as np

# %matplotlib inline

pd_bm=pd.DataFrame.from_records(Benchmark_Port_Value)
pd_bm[0]=pd.to_datetime(pd_bm[0], format='%Y/%m/%d')

x1 = np.array(pd_data1_test['Date'])
y1 = portfolio_value

x2=pd_bm[0]
y2=pd_bm[1]



plt.title("Portfolio Value vs Benchmark Over Test Data")
plt.xlabel("Days")
plt.ylabel("Portfolio Value in $")

plt.plot(x1,y1)
plt.plot_date(x2, y2, c = 'red', marker='v', linestyle='-')


#plt.plot(x1, z, '-', color='black');
plt.plot(x1, y1, '-', color='blue');



#plt.scatter(x1,Benchmark_Port_Value,marker='o')

plt.legend(('Trading Model', 'Benchmark'))

plt.show()
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:24: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
